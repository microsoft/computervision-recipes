# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Testing different Hyperparameters and Benchmarking

# %% [markdown]
# In this notebook, we'll cover how to test different hyperparameters for a particular dataset and how to benchmark different parameters across a group of datasets using AzureML

# %% [markdown]
# Similar to 11_exploring_hyperparameters.ipynb, we will learn more about __how different learning rates and different image sizes affect our model's accuracy when restricted to 10 epochs__, and we want to build an AzureML experiment to test out these hyperparameters.
#
# We present an overall process of utilizing AzureML, specifically [Hyperdrive](https://docs.microsoft.com/en-us/python/api/azureml-train-core/azureml.train.hyperdrive?view=azure-ml-py) component, for the hyperparameter tuning by demonstrating key steps:
# * Configure AzureML Workspace
# * Create Remote Compute Target (GPU cluster)
# * Prepare Data
# * Prepare Training Script
# * Setup and Run Hyperdrive Experiment
# * Model Import, Re-train and Test

# %%
import fastai
from fastai.vision import *

import os
import sys
sys.path.append("../../")

from utils_cv.classification.data import Urls
from utils_cv.common.data import unzip_url

import azureml.core
from azureml.core import Workspace, Experiment
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
import azureml.data
from azureml.train.hyperdrive import RandomParameterSampling, BanditPolicy, HyperDriveConfig, PrimaryMetricGoal, choice
from azureml.train.estimator import Estimator

import azureml.widgets as widgets

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.0.33

# %% [markdown]
# Ensure edits to libraries are loaded and plotting is shown in the notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### 1. Config AzureML workspace
# Below we setup AzureML workspace and get all its details as follows:

# %%
ws = Workspace.setup()
ws_details = ws.get_details()
print('Name:\t\t{}\nLocation:\t{}'
      .format(ws_details['name'],
              ws_details['location']))
# Out:
# Name:		aashna-ws-personal
# Location:	westus2

# %% [markdown]
# ### 2. Create Remote Target
# We create a GPU cluster as our remote compute target. If a cluster with the same name is already exist in our workspace, the script will load it instead. We can see [here](https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-set-up-training-targets) to learn more about setting up a compute target on different locations.
#
# This notebook selects STANDARD_NC6 virtual machine (VM) and sets it's priority as lowpriority to save the cost.

# %%
# choose a name for our cluster
cluster_name = "gpu-cluster-nc6"
# Remote compute (cluster) configuration. If you want to save the cost more, set these to small.
VM_SIZE = 'STANDARD_NC6'
VM_PRIORITY = 'lowpriority'

# Cluster nodes
MIN_NODES = 0
MAX_NODES = 4

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target.')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size=VM_SIZE,
                                                           min_nodes=MIN_NODES,
                                                           max_nodes=MAX_NODES)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

    compute_target.wait_for_completion(show_output=True)

# we can use get_status() to get a detailed status for the current cluster. 
print(compute_target.get_status().serialize())
# Out:
# Found existing compute target.
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Steady', 'allocationStateTransitionTime': '2019-05-16T21:36:50.577000+00:00', 'errors': None, 'creationTime': '2019-05-16T21:36:33.914281+00:00', 'modifiedTime': '2019-05-16T21:37:05.516620+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_NC6'}

# %% [markdown]
# ### 3. Prepare data
# In this notebook, we'll use the Fridge Objects dataset, which is already stored in the correct format. We then upload our data to the AzureML workspace.

# %%
# Note, all the files under DATA_DIR will be uploaded to the data store
DATA = unzip_url(Urls.fridge_objects_path, exist_ok=True)
REPS = 3

ds = ws.get_default_datastore()

ds.upload(
    src_dir=os.path.dirname(DATA),
    target_path='data',
    overwrite=True,
    show_progress=True
)
# Out:
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects.zip
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark.zip
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\1.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\10.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\11.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\12.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\13.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\14.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\15.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\16.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\17.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\18.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\19.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\2.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\20.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\21.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\22.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\23.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\24.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\25.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\26.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\27.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\28.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\29.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\3.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\30.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\31.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\32.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\4.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\5.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\6.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\7.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\7.jpg, 1 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\11.jpg, 2 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\8.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\24.jpg, 3 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\2.jpg, 4 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\10.jpg, 5 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\27.jpg, 6 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\20.jpg, 7 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\17.jpg, 8 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\15.jpg, 9 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\29.jpg, 10 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\26.jpg, 11 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\3.jpg, 12 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\9.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\33.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\34.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\35.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\36.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\37.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\38.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\39.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\40.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\18.jpg, 13 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\41.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\31.jpg, 14 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\25.jpg, 15 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\6.jpg, 16 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\5.jpg, 17 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\13.jpg, 18 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\42.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\19.jpg, 19 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\23.jpg, 20 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\28.jpg, 21 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\16.jpg, 22 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\12.jpg, 23 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\43.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\44.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\45.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\46.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\47.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\48.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\21.jpg, 24 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\22.jpg, 25 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\1.jpg, 26 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\8.jpg, 27 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\49.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\50.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\14.jpg, 28 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\4.jpg, 29 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\32.jpg, 30 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\51.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\52.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\53.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\54.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\55.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\33.jpg, 31 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\9.jpg, 32 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\39.jpg, 33 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\38.jpg, 34 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\56.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\57.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\58.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\59.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\60.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\41.jpg, 35 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\40.jpg, 36 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\37.jpg, 37 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\36.jpg, 38 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\34.jpg, 39 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\42.jpg, 40 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\46.jpg, 41 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\44.jpg, 42 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\35.jpg, 43 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\48.jpg, 44 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\47.jpg, 45 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\61.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\43.jpg, 46 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\62.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\63.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\64.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\45.jpg, 47 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\100.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\101.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\65.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\66.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\67.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\68.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\69.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\70.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\51.jpg, 48 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\71.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\52.jpg, 49 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\72.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\73.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\49.jpg, 50 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\53.jpg, 51 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\74.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\54.jpg, 52 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\55.jpg, 53 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\50.jpg, 54 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\75.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\56.jpg, 55 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\58.jpg, 56 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\57.jpg, 57 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\60.jpg, 58 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\59.jpg, 59 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\76.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\77.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\78.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\79.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\61.jpg, 60 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\62.jpg, 61 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\80.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\81.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\82.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\69.jpg, 62 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\63.jpg, 63 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\83.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\84.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\85.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\86.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\70.jpg, 64 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\100.jpg, 65 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\carton\64.jpg, 66 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\68.jpg, 67 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\87.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\88.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\67.jpg, 68 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\101.jpg, 69 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\66.jpg, 70 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\72.jpg, 71 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\73.jpg, 72 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\71.jpg, 73 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\89.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\65.jpg, 74 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\74.jpg, 75 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\90.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\91.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\92.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\93.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\94.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\95.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\75.jpg, 76 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\76.jpg, 77 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\77.jpg, 78 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\96.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\97.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\98.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\99.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\79.jpg, 79 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\102.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\103.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\104.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\82.jpg, 80 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\105.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\80.jpg, 81 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\78.jpg, 82 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\81.jpg, 83 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\106.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\107.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\84.jpg, 84 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\85.jpg, 85 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\108.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\86.jpg, 86 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\83.jpg, 87 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\89.jpg, 88 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\109.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\110.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\87.jpg, 89 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\111.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\112.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\113.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\90.jpg, 90 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\93.jpg, 91 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\91.jpg, 92 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\88.jpg, 93 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\94.jpg, 94 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\95.jpg, 95 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\92.jpg, 96 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\114.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\115.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\116.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\117.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\118.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\119.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\120.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\121.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\122.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\123.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\97.jpg, 97 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\102.jpg, 98 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\124.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\125.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\103.jpg, 99 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\105.jpg, 100 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\96.jpg, 101 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\99.jpg, 102 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\106.jpg, 103 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\107.jpg, 104 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\104.jpg, 105 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\126.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\108.jpg, 106 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\milk_bottle\98.jpg, 107 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\127.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\128.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\129.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\130.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\131.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\132.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\133.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\109.jpg, 108 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\134.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\1.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\111.jpg, 109 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\110.jpg, 110 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\113.jpg, 111 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\112.jpg, 112 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\118.jpg, 113 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\117.jpg, 114 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\10.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\11.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\116.jpg, 115 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\114.jpg, 116 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\12.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\121.jpg, 117 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\13.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\14.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\15.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\119.jpg, 118 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\125.jpg, 119 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\16.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\115.jpg, 120 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\124.jpg, 121 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\123.jpg, 122 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\17.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\126.jpg, 123 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\18.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\19.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\2.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\122.jpg, 124 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\120.jpg, 125 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\20.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\21.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\22.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\23.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\131.jpg, 126 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\24.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\25.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\127.jpg, 127 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\26.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\132.jpg, 128 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\128.jpg, 129 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\133.jpg, 130 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\134.jpg, 131 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\130.jpg, 132 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\27.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\28.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\water_bottle\129.jpg, 133 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\29.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\3.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\30.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\31.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\32.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\4.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\5.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\6.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\10.jpg, 134 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\14.jpg, 135 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\13.jpg, 136 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\24.jpg, 137 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\1.jpg, 138 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\19.jpg, 139 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\17.jpg, 140 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\20.jpg, 141 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\23.jpg, 142 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\16.jpg, 143 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\22.jpg, 144 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\15.jpg, 145 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\2.jpg, 146 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\29.jpg, 147 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\26.jpg, 148 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\25.jpg, 149 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\11.jpg, 150 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\21.jpg, 151 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\18.jpg, 152 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\28.jpg, 153 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\12.jpg, 154 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\27.jpg, 155 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\7.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\8.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\9.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\33.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\34.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\35.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\36.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\37.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\38.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\39.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\40.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\41.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\3.jpg, 156 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\42.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\43.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\44.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\45.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\46.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\47.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\48.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\49.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\50.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\51.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\32.jpg, 157 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\4.jpg, 158 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\30.jpg, 159 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\5.jpg, 160 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\6.jpg, 161 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\52.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\31.jpg, 162 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\37.jpg, 163 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\34.jpg, 164 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\9.jpg, 165 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\33.jpg, 166 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\7.jpg, 167 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\38.jpg, 168 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\35.jpg, 169 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\53.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\can\8.jpg, 170 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\54.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\55.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\36.jpg, 171 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\56.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\57.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\58.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\59.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\60.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\61.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\62.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\49.jpg, 172 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\39.jpg, 173 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\50.jpg, 174 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\42.jpg, 175 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\46.jpg, 176 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\43.jpg, 177 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\47.jpg, 178 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\48.jpg, 179 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\40.jpg, 180 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\63.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\64.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\100.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\101.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\65.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\41.jpg, 181 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\51.jpg, 182 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\45.jpg, 183 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\44.jpg, 184 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\66.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\67.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\68.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\69.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\70.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\71.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\72.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\73.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\74.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\54.jpg, 185 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\52.jpg, 186 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\75.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\76.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\53.jpg, 187 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\56.jpg, 188 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\55.jpg, 189 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\58.jpg, 190 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\57.jpg, 191 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\59.jpg, 192 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\77.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\78.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\60.jpg, 193 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\79.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\80.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\62.jpg, 194 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\61.jpg, 195 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\101.jpg, 196 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\100.jpg, 197 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\65.jpg, 198 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\63.jpg, 199 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\carton\64.jpg, 200 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\81.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\82.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\83.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\84.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\85.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\86.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\67.jpg, 201 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\69.jpg, 202 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\71.jpg, 203 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\87.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\88.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\89.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\90.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\72.jpg, 204 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\73.jpg, 205 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\91.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\92.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\93.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\70.jpg, 206 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\74.jpg, 207 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\66.jpg, 208 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\94.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\68.jpg, 209 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\75.jpg, 210 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\76.jpg, 211 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\77.jpg, 212 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\95.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\96.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\97.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\98.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\99.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\102.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\103.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\104.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\105.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\106.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\80.jpg, 213 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\107.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\108.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\79.jpg, 214 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\83.jpg, 215 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\78.jpg, 216 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\82.jpg, 217 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\86.jpg, 218 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\85.jpg, 219 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\84.jpg, 220 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\93.jpg, 221 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\89.jpg, 222 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\81.jpg, 223 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\109.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\110.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\111.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\112.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\113.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\114.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\115.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\116.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\117.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\91.jpg, 224 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\87.jpg, 225 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\90.jpg, 226 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\92.jpg, 227 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\88.jpg, 228 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\118.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\119.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\95.jpg, 229 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\97.jpg, 230 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\94.jpg, 231 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\96.jpg, 232 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\120.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\121.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\122.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\123.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\124.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\125.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\126.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\104.jpg, 233 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\127.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\103.jpg, 234 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\102.jpg, 235 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\128.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\107.jpg, 236 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\106.jpg, 237 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\108.jpg, 238 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\105.jpg, 239 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\99.jpg, 240 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\milk_bottle\98.jpg, 241 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\111.jpg, 242 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\109.jpg, 243 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\110.jpg, 244 files out of an estimated total of 270
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\129.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\130.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\131.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\132.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\133.jpg
# Uploading C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\134.jpg
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\113.jpg, 245 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\116.jpg, 246 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\114.jpg, 247 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\112.jpg, 248 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\117.jpg, 249 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\115.jpg, 250 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\119.jpg, 251 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\118.jpg, 252 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\121.jpg, 253 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\122.jpg, 254 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\123.jpg, 255 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\120.jpg, 256 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\128.jpg, 257 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\125.jpg, 258 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\127.jpg, 259 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\126.jpg, 260 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\124.jpg, 261 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\133.jpg, 262 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\134.jpg, 263 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\130.jpg, 264 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\132.jpg, 265 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\131.jpg, 266 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects\water_bottle\129.jpg, 267 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark.zip, 268 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjects.zip, 269 files out of an estimated total of 270
# Uploaded C:\Users\aagarg\source\repos\ComputerVision\data\fridgeObjectsWatermark\can\30.jpg, 270 files out of an estimated total of 270
# $AZUREML_DATAREFERENCE_351d67bf07774a71b09d242513d1f886

# %% [markdown]
# ### 4. Prepare training script
#
# Next step is to prepare scripts that AzureML Hyperdrive will use to train and evaluate models with selected hyperparameters. To run the model notebook from the Hyperdrive Run, all we need is to prepare an entry script which parses the hyperparameter arguments, passes them to the notebook, and records the results of the notebook to AzureML Run logs.

# %%
# creating a folder for the training script here
script_folder = os.path.join(os.getcwd(), "hyperparameter")
os.makedirs(script_folder, exist_ok=True)

# %%
# %%writefile $script_folder/train.py

import numpy as np
import os
from sklearn.externals import joblib
import sys

import fastai
from fastai.vision import *
from fastai.vision.data import *

from azureml.core import Run

run = Run.get_context()

# The datastore is mounted in the Estimator script_params which resolves to an environment variable
# name of the format "$AZUREML_DATAREFERENCE_XXXX" where XXXX is the default datastore 'workspaceblobstore' in this case.
# We retrieve our FridgeObjects dataset by giving the path such as below.
data_store_path = str(os.environ['AZUREML_DATAREFERENCE_workspaceblobstore'])
path = data_store_path + '/data/fridgeObjects'

# Define parameters that we are going to use for training
IM_SIZES = [299, 499]
ARCHITECTURE  = models.resnet50
LEARNING_RATES = [1e-3, 1e-4, 1e-5]
EPOCHS = [10]

# Getting training and validation data and training the CNN as done in 01_training_introduction.ipynb
data = (ImageList.from_folder(path)
        .split_by_rand_pct(valid_pct=0.2, seed=10)
        .label_from_folder() 
        .transform(size=299) 
        .databunch(bs=16) 
        .normalize(imagenet_stats))

learn = cnn_learner(
    data,
    ARCHITECTURE,
    metrics=[accuracy]
)

learn.unfreeze()
learn.fit(EPOCHS[0], LEARNING_RATES[0])

training_losses = [x.numpy().ravel()[0] for x in learn.recorder.losses]
accuracy = [x[0].numpy().ravel()[0] for x in learn.recorder.metrics][-1]

#run.log_list('training_loss', training_losses)
#run.log_list('validation_loss', learn.recorder.val_losses)
#run.log_list('error_rate', error_rate)
#run.log_list('learning_rate', learn.recorder.lrs)
run.log('accuracy', float(accuracy))  # Logging our primary metric 'accuracy'

current_directory = os.getcwd()
output_folder = os.path.join(current_directory, 'outputs')
MODEL_NAME = 'im_classif_resnet50'  # Name we will give our model both locally and on Azure
PICKLED_MODEL_NAME = MODEL_NAME + '.pkl'
os.makedirs(output_folder, exist_ok=True)

learn.export(os.path.join(output_folder, PICKLED_MODEL_NAME))
# Out:
# Overwriting C:\Users\aagarg\source\repos\ComputerVision\classification\notebooks\hyperparameter/train.py

# %% [markdown]
# ### 5. Setup and run Hyperdrive experiment
#
# Next step is to prepare scripts that AzureML Hyperdrive will use to train and evaluate models with selected hyperparameters. To run the model notebook from the Hyperdrive Run, all we need is to prepare an entry script which parses the hyperparameter arguments, passes them to the notebook, and records the results of the notebook to AzureML Run logs.
#
# #### 5.1 Create Experiment
# Experiment is the main entry point into experimenting with AzureML. To create new Experiment or get the existing one, we pass our experimentation name 'hyperparameter-tuning'.

# %%
experiment_name = 'hyperparameter-tuning'
exp = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# #### 5.2. Define search space
#
# Now we define the search space of hyperparameters. For example, if you want to test different batch sizes of {64, 128, 256}, you can use azureml.train.hyperdrive.choice(64, 128, 256). To search from a continuous space, use uniform(start, end). For more options, see [Hyperdrive parameter expressions](https://docs.microsoft.com/en-us/python/api/azureml-train-core/azureml.train.hyperdrive.parameter_expressions?view=azure-ml-py).
#
# In this notebook, we fix model architecture as models.resnet50 and the number of epochs to 10.
# In the search space, we set different learning rates and image sizes. Details about the hyperparameters can be found from our 11_exploring_hyperparameters.ipynb notebook.
#
# Hyperdrive provides three different parameter sampling methods: RandomParameterSampling, GridParameterSampling, and BayesianParameterSampling. Details about each method can be found [here](https://docs.microsoft.com/en-us/azure/machine-learning/service/how-to-tune-hyperparameters). Here, we use the Random Parameter sampling.

# %%
IM_SIZES = [299, 499]
LEARNING_RATES = [1e-3, 1e-4, 1e-5]

# Hyperparameter search space
param_sampling = RandomParameterSampling( {
        'learning_rate': choice(LEARNING_RATES),
        'im_sizes': choice(IM_SIZES)
    }
)

primary_metric_name = 'accuracy'
primary_metric_goal = PrimaryMetricGoal.MAXIMIZE
max_total_runs=50
max_concurrent_runs=4

early_termination_policy = BanditPolicy(slack_factor=0.15, evaluation_interval=1, delay_evaluation=20)

# %% [markdown]
# <b>AzureML Estimator</b> is the building block for training. An Estimator encapsulates the training code and parameters, the compute resources and runtime environment for a particular training scenario.
# We create one for our experimentation with the dependencies our model requires as follows:
#
# ```python
# pip_packages=['fastai']
# conda_packages=['scikit-learn']
# ```

# %%
script_params = {
    '--data-folder': ds.as_mount(),
}

est = Estimator(source_directory=script_folder,
                script_params=script_params,
                compute_target=compute_target,
                entry_script='train.py',
                pip_packages=['fastai'],
                conda_packages=['scikit-learn'])
#model_run = exp.submit(est)
#widgets.RunDetails(model_run).show()

# %% [markdown]
# To the Hyperdrive Run Config, we set our primary metric name and the goal (our hyperparameter search criteria), hyperparameter sampling method, and number of total child-runs. The bigger the search space, the more number of runs we will need for better results.

# %%
hyperdrive_run_config = HyperDriveConfig(estimator=est,
                                         hyperparameter_sampling=param_sampling,
                                         policy=early_termination_policy,
                                         primary_metric_name=primary_metric_name,
                                         primary_metric_goal=primary_metric_goal,
                                         max_total_runs=max_total_runs,
                                         max_concurrent_runs= max_concurrent_runs)

# %% [markdown]
# #### 5.3 Run Experiment
# Now we submit the Run to our experiment. We can see the experiment progress from this notebook by using
# ```python
# azureml.widgets.RunDetails(hyperdrive_run).show()
# ```
# or check from the Azure portal with the url link we get by running
# ```python
# hyperdrive_run.get_portal_url().```
#
# To load an existing Hyperdrive Run instead of start new one, we can use
# ```python
# hyperdrive_run = azureml.train.hyperdrive.HyperDriveRun(exp, <your-run-id>, hyperdrive_run_config=hyperdrive_run_config)
# ```
# We also can cancel the Run with
# ```python
# hyperdrive_run_config.cancel().
# ```

# %%
hyperdrive_run = exp.submit(config=hyperdrive_run_config)
widgets.RunDetails(hyperdrive_run).show()
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…

# %% [markdown]
# Once all the child-runs are finished, we can get the best run and the metrics.

# %%
# Get best run and print out metrics
best_run = hyperdrive_run.get_best_run_by_primary_metric()
best_run_metrics = best_run.get_metrics()
parameter_values = best_run.get_details()['runDefinition']['arguments']
best_parameters = dict(zip(parameter_values[::2], parameter_values[1::2]))

print("* Best Run Id:", best_run.id)
print(best_run)
print("\n* Best hyperparameters:")
print(best_parameters)
print("Accuracy =", best_run_metrics['accuracy'])
#print("Learning Rate =", best_run_metrics['learning_rate'])
# Out:
# * Best Run Id: hyperparameter-tuning_1558052437268_34
# Run(Experiment: hyperparameter-tuning,
# Id: hyperparameter-tuning_1558052437268_34,
# Type: azureml.scriptrun,
# Status: Completed)
#
# * Best hyperparameters:
# {'--data-folder': '$AZUREML_DATAREFERENCE_workspaceblobstore', '--im_sizes': '499', '--learning_rate': '1E-05'}
# Accuracy = 0.8846153616905212

# %% [markdown]
# ### 6. Test the model
#
# We can download the best run model from outputs folder and use it to test against unseen images

# %%
current_directory = os.getcwd()
output_folder = os.path.join(current_directory, 'outputs')
MODEL_NAME = 'im_classif_resnet50'
PICKLED_MODEL_NAME = MODEL_NAME + '.pkl'
os.makedirs(output_folder, exist_ok=True)

for f in best_run.get_file_names():
    if f.startswith('outputs/im_classif_resnet50'):
        print("Downloading {}..".format(f))
        best_run.download_file(name=f, output_file_path=output_folder)
saved_model = load_learner(path = output_folder, file=PICKLED_MODEL_NAME)
print(saved_model)
# Out:
# Downloading outputs/im_classif_resnet50.pkl..
# Learner(data=ImageDataBunch;
#
# Train: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: C:\Users\aagarg\source\repos\ComputerVision\classification\notebooks\outputs;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: C:\Users\aagarg\source\repos\ComputerVision\classification\notebooks\outputs;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25)
#     (4): Linear(in_features=4096, out_features=512, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5)
#     (8): Linear(in_features=512, out_features=4, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x0000028BAAA3AA60>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('C:/Users/aagarg/source/repos/ComputerVision/classification/notebooks/outputs'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU(inplace)
#   (11): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (13): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (14): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace)
#   (20): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (21): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (25): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU(inplace)
#   (27): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (28): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (32): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace)
#   (34): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (37): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (39): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (42): ReLU(inplace)
#   (43): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (44): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (45): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (46): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (47): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (48): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (49): ReLU(inplace)
#   (50): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (51): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (52): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (53): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (54): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (55): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (56): ReLU(inplace)
#   (57): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (58): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (59): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (60): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (61): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (62): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (63): ReLU(inplace)
#   (64): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (65): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (66): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (67): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (68): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (69): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (70): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (71): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (72): ReLU(inplace)
#   (73): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (74): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (75): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (76): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (77): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (78): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (79): ReLU(inplace)
#   (80): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (81): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (82): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (83): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (84): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (85): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (86): ReLU(inplace)
#   (87): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (88): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (89): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (90): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (91): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (92): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (93): ReLU(inplace)
#   (94): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (95): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (96): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (97): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (98): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (99): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (100): ReLU(inplace)
#   (101): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (102): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (103): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (104): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (105): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (106): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (107): ReLU(inplace)
#   (108): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (109): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (110): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (111): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (112): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (113): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (114): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (115): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (116): ReLU(inplace)
#   (117): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (118): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (119): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (120): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (121): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (122): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (123): ReLU(inplace)
#   (124): AdaptiveAvgPool2d(output_size=1)
#   (125): AdaptiveMaxPool2d(output_size=1)
#   (126): Flatten()
#   (127): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (128): Dropout(p=0.25)
#   (129): Linear(in_features=4096, out_features=512, bias=True)
#   (130): ReLU(inplace)
#   (131): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (132): Dropout(p=0.5)
#   (133): Linear(in_features=512, out_features=4, bias=True)
# )], add_time=True, silent=False)

# %% [markdown]
# We can now use the retrieved best run model to get predictions on unseen images as done in 02_training_accuracy_vs_speed.ipynb notebook using
# ```python
# saved_model.predict(image)
# ```

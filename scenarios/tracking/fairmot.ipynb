# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append("../../")
from utils_cv.tracking.model import TrackingLearner
# Out:
# ../../utils_cv/tracking/model.py:116: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(bool(im_path) ^ bool(video_path), "Either im_path or video_path must be defined.")

# %%
tracker = TrackingLearner()

# %%
tracker.predict(
    video_path="../../../data/Famalicao_Half1_Trim_00_45-1_07.mp4",
    load_model="../../utils_cv/tracking/models/all_dla34.pth",
    input_w=3840,
    input_h=800,
    min_box_area=10
)
# Out:
# Namespace(K=128, arch='dla_34', batch_size=12, cat_spec_wh=True, chunk_sizes=[6, 6], conf_thres=0.6, data_cfg='../src/lib/cfg/data.json', data_dir='/data/yfzhang/MOT/JDE', dataset='jde', debug_dir='./exp/mot/default/debug', dense_wh=True, det_thres=0.3, device=device(type='cuda'), down_ratio=4, exp_dir='./exp/mot', exp_id='default', fix_res=False, gpus=[0, 1], gpus_str='0, 1', head_conv=256, heads={'hm': 1, 'wh': 2, 'id': 512}, hide_data_time=True, hm_weight=1, id_loss='ce', id_weight=1, img_size=(3840, 800), input_h=800, input_res=1088, input_video='../videos/MOT16-03.mp4', input_w=3840, keep_res=True, load_model='../../utils_cv/tracking/models/all_dla34.pth', lr=0.0001, lr_step=[20, 27], master_batch_size=6, mean=[0.408, 0.447, 0.47], metric='loss', min_box_area=10, mse_loss=True, nID=14455, nms_thres=0.4, norm_wh=True, not_cuda_benchmark=True, not_prefetch_test=True, not_reg_offset=True, num_classes=1, num_epochs=30, num_iters=-1, num_stacks=1, num_workers=8, off_weight=1, output_
# ...

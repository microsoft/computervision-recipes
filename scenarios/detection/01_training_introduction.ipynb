# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.classification.data import Urls as UrlsIC
from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset, get_transform
from utils_cv.detection.plot import (
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_counts_curves,
    #plot_detection_vs_ground_truth,
    plot_detections
)
from utils_cv.detection.model import (
    DetectionLearner,
    get_pretrained_fasterrcnn,
)
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend("TkAgg")

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0
# Cuda is not available. Torch is using CPU

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
NEG_DATA_PATH = unzip_url(UrlsIC.fridge_objects_negatives_path, exist_ok=True)
EPOCHS = 5 #10
LEARNING_RATE = 0.005
IM_SIZE = 100 #500
SAVE_MODEL = True

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cpu

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['.DS_Store', 'annotations', 'images', 'models']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x000002CE28BEF320>
# Testing dataset: 32 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x000002CE28CF2828>

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\116.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x000002CE288E2CF8>
# <utils_cv.detection.references.transforms.ToTensor object at 0x000002CE288E2DA0>
# <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x000002CE1F0B1240>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, we can pass in the dataset. By default, the object will set the model to torchvision's Faster R-CNN. Alternatively, we can pass in the model we want to use - we would customize the model using the `get_pretrained_fasterrcnn` function and specify the parameters we want.

# %%
detector = DetectionLearner(data, im_size=IM_SIZE)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# Precision-Recall curves can be hard to interpret, and hence we also provide counts how many (left) images have at least one wrong detection / missed ground truth; and (right) the total number of wrong detections / missed ground truths summed over all images. These counts are shown for different detection score thresholds, ie. effectly discarding detections with confidence score lower than a given thresholds.
#
# As can be seen, the model performs well on the test dataset for thresholds between 0.5 and 0.9, but especially at a threshold of 0.5 over-fires on the negative images (images which do not contain any of the objects) since similar images were not included in the training set. This information is especially valuable when deciding on a precision-recall operating point. To avoid over-firing, one can either add more images to the training set directly or via hard-negative mining as explained in the [12_hard_negative_sampling.ipynb](12_hard_negative_sampling.ipynb) notebook.

# %%
# Run detector on the test images. Set threshold to 0 to keep all low confidence detections.
print(f"Running detector on {len(data.test_ds)} test images...")
detections = detector.predict_dl(data.test_dl, threshold=0)

# Run detector on the negative images
if NEG_DATA_PATH is None or NEG_DATA_PATH == "":
    detections_neg = None
else:
    neg_data = DetectionDataset(
        NEG_DATA_PATH,
        train_pct=1.0,  # , batch_size=BATCH_SIZE,
        im_dir="",
        allow_negatives=True,
        train_transforms=get_transform(train=False),
    )
    print(f"Running detector on {len(neg_data.train_ds)} negative images...")
    detections_neg = detector.predict_dl(neg_data.train_dl, threshold=0)

# Count and plot number of wrong/missing detections
plot_counts_curves(detections, data.test_ds, detections_neg)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.0001)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 59,
#   'det_bboxes': [{Bbox object: [left=339, top=218, right=425, bottom=428] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.23041385412216187,
#    {Bbox object: [left=37, top=216, right=177, bottom=512] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.22924016416072845,
#    {Bbox object: [left=4, top=206, right=206, bottom=630] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.2282211035490036,
#    {Bbox object: [left=40, top=259, right=179, bottom=566] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.21765822172164917,
#    {Bbox object: [left=17, top=165, right=227, bottom=568] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.20939823985099792,
#    {Bbox object: [left=37, top=261, right=181, bottom=565] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.18226613104343414,
#    {Bbox object: [left=41, top=259, right=183, bottom=554] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1770804524421692,
#    {Bbox object: [left=51, top=166, right=192, bottom=471] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1758171170949936,
#    {Bbox object: [left=337, top=222, right=424, bottom=426] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.17124593257904053,
#    {Bbox object: [left=229, top=238, right=335, bottom=465] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.16939514875411987,
#    {Bbox object: [left=227, top=235, right=337, bottom=461] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.16779449582099915,
#    {Bbox object: [left=245, top=255, right=344, bottom=469] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.16012434661388397,
#    {Bbox object: [left=52, top=177, right=194, bottom=469] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1494552493095398,
#    {Bbox object: [left=46, top=157, right=190, bottom=484] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.14781858026981354,
#    {Bbox object: [left=338, top=213, right=424, bottom=428] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.14542679488658905,
#    {Bbox object: [left=338, top=216, right=424, bottom=423] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.14186859130859375,
#    {Bbox object: [left=244, top=259, right=345, bottom=469] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.14169557392597198,
#    {Bbox object: [left=6, top=279, right=185, bottom=666] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.13771405816078186,
#    {Bbox object: [left=0, top=209, right=204, bottom=637] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1350911259651184,
#    {Bbox object: [left=248, top=292, right=349, bottom=502] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1333795189857483,
#    {Bbox object: [left=47, top=254, right=268, bottom=666] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.13050583004951477,
#    {Bbox object: [left=244, top=296, right=349, bottom=500] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.1284022331237793,
#    {Bbox object: [left=223, top=222, right=434, bottom=467] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.12492606043815613,
#    {Bbox object: [left=188, top=230, right=367, bottom=463] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.12006780505180359,
#    {Bbox object: [left=226, top=222, right=433, bottom=470] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.11859503388404846,
#    {Bbox object: [left=7, top=240, right=208, bottom=413] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.10990749299526215,
#    {Bbox object: [left=5, top=320, right=202, bottom=469] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.10675548017024994,
#    {Bbox object: [left=221, top=219, right=430, bottom=469] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.10643008351325989,
#    {Bbox object: [left=34, top=245, right=259, bottom=666] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.10338485985994339,
#    {Bbox object: [left=38, top=340, right=211, bottom=581] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.09800402075052261,
#    {Bbox object: [left=194, top=292, right=361, bottom=499] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.09709169715642929,
#    {Bbox object: [left=12, top=139, right=299, bottom=549] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.09238504618406296,
#    {Bbox object: [left=0, top=46, right=182, bottom=516] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.09122451394796371,
#    {Bbox object: [left=227, top=267, right=417, bottom=500] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08917083591222763,
#    {Bbox object: [left=158, top=250, right=365, bottom=479] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.0888126865029335,
#    {Bbox object: [left=0, top=300, right=227, bottom=455] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08827529102563858,
#    {Bbox object: [left=8, top=314, right=200, bottom=469] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08698603510856628,
#    {Bbox object: [left=162, top=257, right=360, bottom=484] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08636564016342163,
#    {Bbox object: [left=10, top=61, right=184, bottom=543] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08523684740066528,
#    {Bbox object: [left=12, top=245, right=212, bottom=409] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.0843106061220169,
#    {Bbox object: [left=221, top=212, right=324, bottom=425] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08335717022418976,
#    {Bbox object: [left=223, top=217, right=328, bottom=417] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.08108693361282349,
#    {Bbox object: [left=10, top=306, right=223, bottom=445] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.07872724533081055,
#    {Bbox object: [left=164, top=177, right=463, bottom=541] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.07523630559444427,
#    {Bbox object: [left=0, top=271, right=166, bottom=415] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.07196841388940811,
#    {Bbox object: [left=170, top=197, right=465, bottom=551] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.07078473269939423,
#    {Bbox object: [left=316, top=207, right=473, bottom=437] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06981243938207626,
#    {Bbox object: [left=0, top=224, right=253, bottom=405] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06746356189250946,
#    {Bbox object: [left=189, top=286, right=429, bottom=418] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06743722409009933,
#    {Bbox object: [left=0, top=138, right=291, bottom=539] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06726983189582825,
#    {Bbox object: [left=270, top=219, right=445, bottom=456] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06635820865631104,
#    {Bbox object: [left=182, top=176, right=371, bottom=426] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.0629572868347168,
#    {Bbox object: [left=181, top=168, right=376, bottom=423] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06286261230707169,
#    {Bbox object: [left=166, top=175, right=458, bottom=544] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06223857402801514,
#    {Bbox object: [left=11, top=372, right=184, bottom=601] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.0614188127219677,
#    {Bbox object: [left=10, top=259, right=212, bottom=402] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06137692928314209,
#    {Bbox object: [left=163, top=176, right=458, bottom=544] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.06030962988734245,
#    {Bbox object: [left=19, top=175, right=336, bottom=569] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05916493758559227,
#    {Bbox object: [left=14, top=213, right=126, bottom=507] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05907026678323746,
#    {Bbox object: [left=178, top=170, right=368, bottom=431] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05779016762971878,
#    {Bbox object: [left=23, top=224, right=381, bottom=529] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.057579752057790756,
#    {Bbox object: [left=43, top=171, right=167, bottom=389] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.056472841650247574,
#    {Bbox object: [left=0, top=358, right=198, bottom=493] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05476348474621773,
#    {Bbox object: [left=9, top=352, right=191, bottom=488] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.053613368421792984,
#    {Bbox object: [left=199, top=284, right=427, bottom=412] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05339839681982994,
#    {Bbox object: [left=290, top=255, right=461, bottom=463] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.053170669823884964,
#    {Bbox object: [left=1, top=295, right=149, bottom=427] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\37.jpg} | score: 0.05077589675784111],
#   'im_path': 'C:\\Users\\pabuehle\\Desktop\\ComputerVision\\data\\odFridgeObjects\\images\\37.jpg'},
#  {'idx': 105,
#   'det_bboxes': [{Bbox object: [left=340, top=222, right=439, bottom=462] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.2251073122024536,
#    {Bbox object: [left=246, top=208, right=361, bottom=468] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.2218228429555893,
#    {Bbox object: [left=57, top=364, right=253, bottom=564] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.22122155129909515,
#    {Bbox object: [left=58, top=303, right=263, bottom=529] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.21275849640369415,
#    {Bbox object: [left=64, top=357, right=213, bottom=560] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.19871249794960022,
#    {Bbox object: [left=338, top=223, right=439, bottom=462] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.19854134321212769,
#    {Bbox object: [left=245, top=211, right=359, bottom=466] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1982915997505188,
#    {Bbox object: [left=215, top=165, right=404, bottom=444] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.19760547578334808,
#    {Bbox object: [left=212, top=162, right=408, bottom=445] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1786426305770874,
#    {Bbox object: [left=68, top=354, right=209, bottom=556] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.17807351052761078,
#    {Bbox object: [left=243, top=239, right=456, bottom=487] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.17558343708515167,
#    {Bbox object: [left=244, top=209, right=358, bottom=468] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.17530278861522675,
#    {Bbox object: [left=243, top=206, right=358, bottom=463] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.17351944744586945,
#    {Bbox object: [left=340, top=221, right=438, bottom=460] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1713390350341797,
#    {Bbox object: [left=90, top=311, right=236, bottom=549] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.16843228042125702,
#    {Bbox object: [left=32, top=405, right=284, bottom=549] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.16411615908145905,
#    {Bbox object: [left=249, top=237, right=459, bottom=492] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.15931503474712372,
#    {Bbox object: [left=339, top=220, right=437, bottom=465] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.15128594636917114,
#    {Bbox object: [left=105, top=312, right=282, bottom=534] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.15103358030319214,
#    {Bbox object: [left=123, top=314, right=244, bottom=516] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1502426713705063,
#    {Bbox object: [left=14, top=381, right=268, bottom=531] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.14857636392116547,
#    {Bbox object: [left=216, top=122, right=419, bottom=486] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1474626362323761,
#    {Bbox object: [left=243, top=239, right=452, bottom=489] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1445651650428772,
#    {Bbox object: [left=0, top=383, right=266, bottom=534] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.13754695653915405,
#    {Bbox object: [left=208, top=160, right=399, bottom=445] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.13581746816635132,
#    {Bbox object: [left=35, top=337, right=272, bottom=480] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.13050808012485504,
#    {Bbox object: [left=49, top=416, right=209, bottom=562] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.12997882068157196,
#    {Bbox object: [left=243, top=143, right=357, bottom=375] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.12484331429004669,
#    {Bbox object: [left=9, top=410, right=206, bottom=545] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.11870617419481277,
#    {Bbox object: [left=367, top=198, right=450, bottom=415] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.11620505899190903,
#    {Bbox object: [left=10, top=362, right=233, bottom=494] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.1146380826830864,
#    {Bbox object: [left=75, top=297, right=209, bottom=512] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.11202248185873032,
#    {Bbox object: [left=38, top=250, right=270, bottom=654] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.11163307726383209,
#    {Bbox object: [left=210, top=248, right=439, bottom=403] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.10507939010858536,
#    {Bbox object: [left=46, top=322, right=168, bottom=523] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.10466387867927551,
#    {Bbox object: [left=24, top=336, right=267, bottom=485] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09723551571369171,
#    {Bbox object: [left=11, top=346, right=285, bottom=639] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09371116012334824,
#    {Bbox object: [left=210, top=96, right=498, bottom=500] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09312466531991959,
#    {Bbox object: [left=284, top=209, right=469, bottom=454] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09244571626186371,
#    {Bbox object: [left=42, top=341, right=268, bottom=474] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09197769314050674,
#    {Bbox object: [left=49, top=330, right=170, bottom=528] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.09092200547456741,
#    {Bbox object: [left=47, top=400, right=162, bottom=559] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.0898226946592331,
#    {Bbox object: [left=364, top=191, right=438, bottom=379] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08921138197183609,
#    {Bbox object: [left=182, top=231, right=416, bottom=388] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08889616280794144,
#    {Bbox object: [left=43, top=257, right=267, bottom=663] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08782148361206055,
#    {Bbox object: [left=212, top=260, right=442, bottom=393] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08779097348451614,
#    {Bbox object: [left=257, top=285, right=388, bottom=526] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08442828059196472,
#    {Bbox object: [left=129, top=375, right=259, bottom=576] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08422642201185226,
#    {Bbox object: [left=217, top=116, right=495, bottom=504] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08403686434030533,
#    {Bbox object: [left=51, top=267, right=265, bottom=657] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08365973830223083,
#    {Bbox object: [left=41, top=422, right=184, bottom=576] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08350711315870285,
#    {Bbox object: [left=190, top=232, right=420, bottom=385] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08342535048723221,
#    {Bbox object: [left=244, top=146, right=357, bottom=370] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08318626135587692,
#    {Bbox object: [left=125, top=172, right=423, bottom=552] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08220468461513519,
#    {Bbox object: [left=92, top=428, right=217, bottom=567] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08187432587146759,
#    {Bbox object: [left=130, top=286, right=239, bottom=470] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08131134510040283,
#    {Bbox object: [left=95, top=424, right=219, bottom=571] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08009964227676392,
#    {Bbox object: [left=132, top=101, right=433, bottom=483] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.08009622246026993,
#    {Bbox object: [left=267, top=279, right=389, bottom=529] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07940865308046341,
#    {Bbox object: [left=308, top=198, right=466, bottom=416] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07798726111650467,
#    {Bbox object: [left=133, top=277, right=238, bottom=478] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07782144099473953,
#    {Bbox object: [left=126, top=377, right=255, bottom=563] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.077520951628685,
#    {Bbox object: [left=47, top=327, right=167, bottom=537] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07599258422851562,
#    {Bbox object: [left=228, top=173, right=389, bottom=385] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07480193674564362,
#    {Bbox object: [left=138, top=367, right=257, bottom=571] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07461068779230118,
#    {Bbox object: [left=56, top=436, right=218, bottom=594] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07459557056427002,
#    {Bbox object: [left=308, top=191, right=469, bottom=409] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.0744580402970314,
#    {Bbox object: [left=119, top=172, right=431, bottom=561] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07427346706390381,
#    {Bbox object: [left=123, top=194, right=439, bottom=559] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.0739731565117836,
#    {Bbox object: [left=239, top=136, right=352, bottom=385] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.07083941251039505,
#    {Bbox object: [left=42, top=384, right=144, bottom=572] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06953979283571243,
#    {Bbox object: [left=115, top=408, right=240, bottom=565] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06858596950769424,
#    {Bbox object: [left=348, top=161, right=431, bottom=387] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06768189370632172,
#    {Bbox object: [left=44, top=147, right=273, bottom=564] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06732789427042007,
#    {Bbox object: [left=132, top=281, right=236, bottom=473] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06681818515062332,
#    {Bbox object: [left=214, top=273, right=496, bottom=415] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06632886081933975,
#    {Bbox object: [left=202, top=279, right=493, bottom=418] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06576097011566162,
#    {Bbox object: [left=256, top=296, right=387, bottom=517] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06379225105047226,
#    {Bbox object: [left=85, top=392, right=355, bottom=542] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06241828203201294,
#    {Bbox object: [left=260, top=282, right=383, bottom=511] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.06023450940847397,
#    {Bbox object: [left=205, top=204, right=431, bottom=645] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.059121377766132355,
#    {Bbox object: [left=10, top=315, right=189, bottom=515] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05894288420677185,
#    {Bbox object: [left=369, top=274, right=464, bottom=508] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.058819130063056946,
#    {Bbox object: [left=220, top=232, right=493, bottom=585] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.058221861720085144,
#    {Bbox object: [left=301, top=188, right=464, bottom=417] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05819106101989746,
#    {Bbox object: [left=88, top=361, right=344, bottom=504] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05380944907665253,
#    {Bbox object: [left=53, top=169, right=370, bottom=572] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05350151285529137,
#    {Bbox object: [left=362, top=188, right=438, bottom=383] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05278554558753967,
#    {Bbox object: [left=363, top=286, right=467, bottom=505] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05159217491745949,
#    {Bbox object: [left=71, top=400, right=335, bottom=539] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\79.jpg} | score: 0.05050590634346008],
#   'im_path': 'C:\\Users\\pabuehle\\Desktop\\ComputerVision\\data\\odFridgeObjects\\images\\79.jpg'},
#  {'idx': 58,
#   'det_bboxes': [{Bbox object: [left=179, top=204, right=304, bottom=483] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.23238274455070496,
#    {Bbox object: [left=297, top=224, right=386, bottom=473] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.2290247231721878,
#    {Bbox object: [left=43, top=354, right=172, bottom=584] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.21993501484394073,
#    {Bbox object: [left=18, top=338, right=206, bottom=588] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.21045544743537903,
#    {Bbox object: [left=44, top=349, right=170, bottom=578] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.2099689096212387,
#    {Bbox object: [left=307, top=213, right=389, bottom=438] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.204428032040596,
#    {Bbox object: [left=164, top=222, right=288, bottom=510] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.20426982641220093,
#    {Bbox object: [left=42, top=308, right=164, bottom=539] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.20010191202163696,
#    {Bbox object: [left=11, top=282, right=207, bottom=558] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1845996379852295,
#    {Bbox object: [left=312, top=191, right=383, bottom=394] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.18316709995269775,
#    {Bbox object: [left=39, top=346, right=170, bottom=586] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.17867153882980347,
#    {Bbox object: [left=39, top=410, right=166, bottom=615] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.17549027502536774,
#    {Bbox object: [left=176, top=204, right=301, bottom=487] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.17320233583450317,
#    {Bbox object: [left=162, top=219, right=286, bottom=503] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1715606451034546,
#    {Bbox object: [left=163, top=269, right=290, bottom=569] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1661006659269333,
#    {Bbox object: [left=16, top=283, right=206, bottom=560] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.16595448553562164,
#    {Bbox object: [left=147, top=164, right=320, bottom=430] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.163438618183136,
#    {Bbox object: [left=295, top=216, right=384, bottom=468] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.15937919914722443,
#    {Bbox object: [left=307, top=205, right=388, bottom=443] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.15357105433940887,
#    {Bbox object: [left=3, top=279, right=208, bottom=570] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.15160155296325684,
#    {Bbox object: [left=264, top=198, right=405, bottom=420] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.14786382019519806,
#    {Bbox object: [left=327, top=214, right=418, bottom=460] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1454494297504425,
#    {Bbox object: [left=260, top=191, right=412, bottom=417] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1396249234676361,
#    {Bbox object: [left=105, top=117, right=327, bottom=530] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.13049183785915375,
#    {Bbox object: [left=35, top=431, right=188, bottom=617] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.124208003282547,
#    {Bbox object: [left=111, top=139, right=334, bottom=534] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.12314022332429886,
#    {Bbox object: [left=40, top=434, right=195, bottom=628] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.12227693200111389,
#    {Bbox object: [left=107, top=129, right=329, bottom=543] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11859319359064102,
#    {Bbox object: [left=4, top=391, right=167, bottom=528] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11762070655822754,
#    {Bbox object: [left=159, top=273, right=288, bottom=567] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11758965253829956,
#    {Bbox object: [left=0, top=361, right=221, bottom=508] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11588173359632492,
#    {Bbox object: [left=3, top=393, right=166, bottom=528] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11473985761404037,
#    {Bbox object: [left=50, top=354, right=260, bottom=666] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11242417246103287,
#    {Bbox object: [left=28, top=439, right=196, bottom=624] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11236586421728134,
#    {Bbox object: [left=26, top=276, right=142, bottom=511] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11229396611452103,
#    {Bbox object: [left=195, top=175, right=317, bottom=450] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.11069616675376892,
#    {Bbox object: [left=286, top=266, right=382, bottom=503] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10883397608995438,
#    {Bbox object: [left=264, top=194, right=409, bottom=417] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10838980972766876,
#    {Bbox object: [left=16, top=228, right=298, bottom=624] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1066540852189064,
#    {Bbox object: [left=102, top=124, right=326, bottom=533] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10584192723035812,
#    {Bbox object: [left=3, top=348, right=148, bottom=666] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1035224050283432,
#    {Bbox object: [left=140, top=170, right=258, bottom=466] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1009441539645195,
#    {Bbox object: [left=5, top=335, right=151, bottom=663] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10047563165426254,
#    {Bbox object: [left=16, top=366, right=218, bottom=500] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.1004604622721672,
#    {Bbox object: [left=40, top=238, right=246, bottom=549] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10014530271291733,
#    {Bbox object: [left=4, top=148, right=185, bottom=580] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.10008196532726288,
#    {Bbox object: [left=28, top=273, right=142, bottom=524] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09905125200748444,
#    {Bbox object: [left=192, top=214, right=412, bottom=481] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09838537871837616,
#    {Bbox object: [left=190, top=213, right=417, bottom=474] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09776964038610458,
#    {Bbox object: [left=31, top=281, right=144, bottom=515] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09668416529893875,
#    {Bbox object: [left=12, top=417, right=169, bottom=544] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09638349711894989,
#    {Bbox object: [left=45, top=346, right=256, bottom=666] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09329873323440552,
#    {Bbox object: [left=286, top=268, right=385, bottom=506] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09315331280231476,
#    {Bbox object: [left=256, top=191, right=405, bottom=426] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09242213517427444,
#    {Bbox object: [left=13, top=289, right=321, bottom=666] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09167633950710297,
#    {Bbox object: [left=0, top=421, right=175, bottom=553] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09103177487850189,
#    {Bbox object: [left=199, top=302, right=321, bottom=525] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.09093711525201797,
#    {Bbox object: [left=111, top=284, right=363, bottom=418] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0908423364162445,
#    {Bbox object: [left=167, top=274, right=370, bottom=541] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0893699899315834,
#    {Bbox object: [left=70, top=251, right=182, bottom=507] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08861564099788666,
#    {Bbox object: [left=32, top=347, right=261, bottom=666] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08681271970272064,
#    {Bbox object: [left=166, top=159, right=357, bottom=441] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08669677376747131,
#    {Bbox object: [left=159, top=160, right=305, bottom=375] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08590025454759598,
#    {Bbox object: [left=187, top=167, right=291, bottom=384] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08566585928201675,
#    {Bbox object: [left=0, top=334, right=144, bottom=666] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08513527363538742,
#    {Bbox object: [left=25, top=353, right=282, bottom=509] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08360761404037476,
#    {Bbox object: [left=121, top=279, right=366, bottom=418] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0833200067281723,
#    {Bbox object: [left=143, top=168, right=253, bottom=474] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08246617764234543,
#    {Bbox object: [left=3, top=221, right=298, bottom=627] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08217662572860718,
#    {Bbox object: [left=147, top=222, right=363, bottom=400] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0813123807311058,
#    {Bbox object: [left=98, top=219, right=413, bottom=596] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0806376114487648,
#    {Bbox object: [left=104, top=235, right=415, bottom=607] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.08027709275484085,
#    {Bbox object: [left=8, top=218, right=293, bottom=623] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07399806380271912,
#    {Bbox object: [left=79, top=191, right=283, bottom=448] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07304347306489944,
#    {Bbox object: [left=91, top=218, right=412, bottom=593] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07190821319818497,
#    {Bbox object: [left=323, top=214, right=417, bottom=456] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0716702863574028,
#    {Bbox object: [left=22, top=355, right=293, bottom=505] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0716041624546051,
#    {Bbox object: [left=187, top=210, right=408, bottom=473] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07110457867383957,
#    {Bbox object: [left=4, top=437, right=157, bottom=570] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0709247961640358,
#    {Bbox object: [left=123, top=286, right=356, bottom=413] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07047926634550095,
#    {Bbox object: [left=192, top=303, right=315, bottom=511] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.07003159821033478,
#    {Bbox object: [left=71, top=244, right=183, bottom=510] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.06889928132295609,
#    {Bbox object: [left=188, top=322, right=319, bottom=517] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.06817787885665894,
#    {Bbox object: [left=71, top=247, right=181, bottom=514] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.06748249381780624,
#    {Bbox object: [left=85, top=200, right=287, bottom=445] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.06706039607524872,
#    {Bbox object: [left=71, top=250, right=183, bottom=510] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\36.jpg} | score: 0.0634295865893364,
# ...
#    {Bbox object: [left=38, top=282, right=162, bottom=505] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.15974341332912445,
#    {Bbox object: [left=258, top=303, right=451, bottom=511] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.15697233378887177,
#    {Bbox object: [left=101, top=278, right=293, bottom=516] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.15485580265522003,
#    {Bbox object: [left=261, top=303, right=453, bottom=512] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.1509696990251541,
#    {Bbox object: [left=257, top=327, right=353, bottom=486] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.14368829131126404,
#    {Bbox object: [left=122, top=168, right=274, bottom=371] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.13737189769744873,
#    {Bbox object: [left=71, top=244, right=280, bottom=501] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.13723795115947723,
#    {Bbox object: [left=27, top=177, right=323, bottom=553] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.13536250591278076,
#    {Bbox object: [left=67, top=247, right=276, bottom=507] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.13200242817401886,
#    {Bbox object: [left=336, top=331, right=452, bottom=520] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.1318388730287552,
#    {Bbox object: [left=69, top=242, right=279, bottom=502] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.12911155819892883,
#    {Bbox object: [left=320, top=317, right=492, bottom=445] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.1280168890953064,
#    {Bbox object: [left=31, top=189, right=329, bottom=559] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.12721894681453705,
#    {Bbox object: [left=259, top=325, right=350, bottom=495] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.12474257498979568,
#    {Bbox object: [left=169, top=268, right=289, bottom=517] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.12321288138628006,
#    {Bbox object: [left=26, top=340, right=131, bottom=519] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.11657930165529251,
#    {Bbox object: [left=108, top=249, right=308, bottom=407] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.11260124295949936,
#    {Bbox object: [left=263, top=317, right=474, bottom=442] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.11194433271884918,
#    {Bbox object: [left=4, top=177, right=186, bottom=558] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.11135411262512207,
#    {Bbox object: [left=97, top=256, right=312, bottom=409] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10889357328414917,
#    {Bbox object: [left=234, top=281, right=426, bottom=491] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10771607607603073,
#    {Bbox object: [left=313, top=254, right=494, bottom=500] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10691627115011215,
#    {Bbox object: [left=269, top=315, right=473, bottom=439] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.1036033034324646,
#    {Bbox object: [left=19, top=174, right=317, bottom=559] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10337507724761963,
#    {Bbox object: [left=65, top=274, right=314, bottom=416] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10074795037508011,
#    {Bbox object: [left=116, top=145, right=227, bottom=446] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.10064887255430222,
#    {Bbox object: [left=160, top=274, right=284, bottom=500] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09880310297012329,
#    {Bbox object: [left=159, top=285, right=287, bottom=507] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0987517312169075,
#    {Bbox object: [left=18, top=176, right=319, bottom=556] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09790012985467911,
#    {Bbox object: [left=319, top=322, right=490, bottom=441] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09760202467441559,
#    {Bbox object: [left=232, top=282, right=424, bottom=497] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0965707078576088,
#    {Bbox object: [left=307, top=259, right=415, bottom=474] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09633391350507736,
#    {Bbox object: [left=107, top=263, right=307, bottom=403] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0954940989613533,
#    {Bbox object: [left=8, top=193, right=183, bottom=560] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09128481149673462,
#    {Bbox object: [left=164, top=155, right=278, bottom=423] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.09113167226314545,
#    {Bbox object: [left=233, top=235, right=489, bottom=575] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08953087776899338,
#    {Bbox object: [left=244, top=260, right=498, bottom=589] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08780248463153839,
#    {Bbox object: [left=239, top=233, right=494, bottom=581] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08672073483467102,
#    {Bbox object: [left=214, top=344, right=361, bottom=518] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08347957581281662,
#    {Bbox object: [left=134, top=130, right=385, bottom=515] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08201530575752258,
#    {Bbox object: [left=364, top=250, right=499, bottom=503] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08180573582649231,
#    {Bbox object: [left=5, top=338, right=187, bottom=460] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08142750710248947,
#    {Bbox object: [left=282, top=289, right=469, bottom=417] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08082623034715652,
#    {Bbox object: [left=139, top=145, right=376, bottom=514] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08067508041858673,
#    {Bbox object: [left=46, top=301, right=328, bottom=456] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.08015938848257065,
#    {Bbox object: [left=167, top=169, right=282, bottom=420] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0798843652009964,
#    {Bbox object: [left=6, top=334, right=182, bottom=463] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07988075911998749,
#    {Bbox object: [left=0, top=341, right=185, bottom=463] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0797744020819664,
#    {Bbox object: [left=1, top=182, right=178, bottom=569] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07783111184835434,
#    {Bbox object: [left=33, top=309, right=263, bottom=460] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07777780294418335,
#    {Bbox object: [left=187, top=339, right=436, bottom=459] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07746133208274841,
#    {Bbox object: [left=122, top=293, right=340, bottom=522] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07537166029214859,
#    {Bbox object: [left=30, top=208, right=139, bottom=432] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07465536147356033,
#    {Bbox object: [left=31, top=206, right=141, bottom=429] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07430572062730789,
#    {Bbox object: [left=309, top=269, right=412, bottom=489] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07395868003368378,
#    {Bbox object: [left=367, top=249, right=497, bottom=487] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07366489619016647,
#    {Bbox object: [left=29, top=206, right=138, bottom=448] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07245707511901855,
#    {Bbox object: [left=130, top=293, right=348, bottom=531] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07240283489227295,
#    {Bbox object: [left=87, top=313, right=370, bottom=454] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07071488350629807,
#    {Bbox object: [left=189, top=346, right=441, bottom=467] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.07016841322183609,
#    {Bbox object: [left=12, top=341, right=181, bottom=459] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06995309889316559,
#    {Bbox object: [left=209, top=349, right=362, bottom=512] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06944930553436279,
#    {Bbox object: [left=197, top=341, right=433, bottom=463] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06844266504049301,
#    {Bbox object: [left=232, top=233, right=490, bottom=583] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0658428966999054,
#    {Bbox object: [left=0, top=295, right=153, bottom=433] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06495822966098785,
#    {Bbox object: [left=214, top=351, right=362, bottom=521] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.0644865408539772,
#    {Bbox object: [left=130, top=132, right=367, bottom=510] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06122441217303276,
#    {Bbox object: [left=131, top=133, right=369, bottom=513] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.06031879037618637,
#    {Bbox object: [left=210, top=352, right=360, bottom=519] | <water_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05985699221491814,
#    {Bbox object: [left=54, top=340, right=188, bottom=551] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.059785015881061554,
#    {Bbox object: [left=137, top=156, right=244, bottom=357] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05860251933336258,
#    {Bbox object: [left=65, top=331, right=186, bottom=548] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05832395330071449,
#    {Bbox object: [left=4, top=292, right=156, bottom=424] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05755184590816498,
#    {Bbox object: [left=47, top=288, right=499, bottom=528] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05736713483929634,
#    {Bbox object: [left=32, top=217, right=140, bottom=434] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05707261338829994,
#    {Bbox object: [left=365, top=247, right=441, bottom=401] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05582991987466812,
#    {Bbox object: [left=316, top=362, right=432, bottom=532] | <carton> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.053575195372104645,
#    {Bbox object: [left=34, top=310, right=257, bottom=460] | <can> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05190141499042511,
#    {Bbox object: [left=317, top=242, right=408, bottom=449] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.05122627690434456,
#    {Bbox object: [left=56, top=282, right=499, bottom=537] | <milk_bottle> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\90.jpg} | score: 0.050102923065423965],
#   'im_path': 'C:\\Users\\pabuehle\\Desktop\\ComputerVision\\data\\odFridgeObjects\\images\\90.jpg'}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(
    f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}"
)
# Out:
# Number of detections: 32
# Number of test images: 32

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def _grid_helper() -> Iterator:
    for detection in detections:
        yield detection, data, None
plot_grid(plot_detections, _grid_helper(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# WindowsPath('C:/Users/pabuehle/Desktop/ComputerVision/data/odFridgeObjects/images/39.jpg')

# %% [markdown]
# We can use the inference function, which accepts either an image or a path to an image as input.

# %%
detections = detector.predict(new_im_path, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_detections(detections)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x666 at 0x2CE28CF2F98>

# %% [markdown]
# ## Save the model
# The final step is to save the model to disk. We'll do this since the deployment notebook will deploy this model.

# %%
if SAVE_MODEL:
    detector.save("my_drink_detector")
# Out:
# Model is saved to C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\models\my_drink_detector

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

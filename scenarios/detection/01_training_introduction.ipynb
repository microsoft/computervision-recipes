# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0a0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['images', 'annotations', '.DS_Store']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)
# Out:
# ../../utils_cv/detection/dataset.py:97: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   if root.find("path"):

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f205ff70fd0>
# Testing dataset: 33 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f205fe6ff28>

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on /home/jiata/code/computervision/data/odFridgeObjects/images/88.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x7f20005b44e0>
# <utils_cv.detection.references.transforms.ToTensor object at 0x7f20005b4518>
# <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x7f20005b45c0>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, the only required parameter is the dataset. The object will set the model to torchvision's Faster R-CNN using the default parameters. However, we can customize the model using the `get_pretrained_fasterrcnn` function and specifying the parameters we want.

# %%
model = get_pretrained_fasterrcnn(
    num_classes=len(data.labels) + 1, min_size=IM_SIZE, max_size=IM_SIZE
)

# %% [markdown]
# We can now pass our Detection Learner object the model.

# %%
detector = DetectionLearner(data, model=model)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:37  lr: 0.000111  loss: 1.7163 (1.7163)  loss_classifier: 1.6112 (1.6112)  loss_box_reg: 0.1039 (0.1039)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 3.2712  data: 0.9384  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:03  lr: 0.003300  loss: 0.5076 (0.7409)  loss_classifier: 0.2562 (0.4998)  loss_box_reg: 0.2484 (0.2285)  loss_objectness: 0.0047 (0.0062)  loss_rpn_box_reg: 0.0067 (0.0064)  time: 0.0828  data: 0.0056  max mem: 958
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3520 (0.5956)  loss_classifier: 0.1807 (0.3850)  loss_box_reg: 0.1494 (0.1984)  loss_objectness: 0.0018 (0.0051)  loss_rpn_box_reg: 0.0059 (0.0069)  time: 0.0813  data: 0.0045  max mem: 958
# Epoch: [0] Total time: 0:00:07 (0.1515 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0898 (0.0898)  evaluator_time: 0.0051 (0.0051)  time: 0.9321  data: 0.8347  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0394)  evaluator_time: 0.0046 (0.0044)  time: 0.0987  data: 0.0530  max mem: 958
# Test: Total time: 0:00:01 (0.1050 s / it)
# Averaged stats: model_time: 0.0299 (0.0394)  evaluator_time: 0.0046 (0.0044)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.527
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.591
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.528
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.683
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.683
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
# Epoch: [1]  [ 0/48]  eta: 0:00:57  lr: 0.005000  loss: 0.2988 (0.2988)  loss_classifier: 0.1957 (0.1957)  loss_box_reg: 0.0929 (0.0929)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0099 (0.0099)  time: 1.2045  data: 0.9398  max mem: 958
# Epoch: [1]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.1050 (0.1469)  loss_classifier: 0.0730 (0.0932)  loss_box_reg: 0.0302 (0.0448)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0073 (0.0077)  time: 0.0820  data: 0.0040  max mem: 958
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0955 (0.1342)  loss_classifier: 0.0570 (0.0833)  loss_box_reg: 0.0300 (0.0418)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0078 (0.0077)  time: 0.0809  data: 0.0046  max mem: 958
# Epoch: [1] Total time: 0:00:05 (0.1117 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0459 (0.0459)  evaluator_time: 0.0042 (0.0042)  time: 0.9204  data: 0.8678  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0305)  evaluator_time: 0.0040 (0.0038)  time: 0.0924  data: 0.0561  max mem: 958
# Test: Total time: 0:00:01 (0.0991 s / it)
# Averaged stats: model_time: 0.0300 (0.0305)  evaluator_time: 0.0040 (0.0038)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.730
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.912
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.730
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.782
# Epoch: [2]  [ 0/48]  eta: 0:00:57  lr: 0.005000  loss: 0.1214 (0.1214)  loss_classifier: 0.0730 (0.0730)  loss_box_reg: 0.0362 (0.0362)  loss_objectness: 0.0030 (0.0030)  loss_rpn_box_reg: 0.0092 (0.0092)  time: 1.2034  data: 0.9474  max mem: 958
# Epoch: [2]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0512 (0.0694)  loss_classifier: 0.0285 (0.0403)  loss_box_reg: 0.0185 (0.0227)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0046 (0.0056)  time: 0.0806  data: 0.0038  max mem: 958
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0445 (0.0657)  loss_classifier: 0.0247 (0.0380)  loss_box_reg: 0.0152 (0.0215)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0045 (0.0055)  time: 0.0805  data: 0.0040  max mem: 958
# Epoch: [2] Total time: 0:00:05 (0.1124 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0487 (0.0487)  evaluator_time: 0.0046 (0.0046)  time: 0.9323  data: 0.8764  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0306)  evaluator_time: 0.0036 (0.0034)  time: 0.0931  data: 0.0572  max mem: 958
# Test: Total time: 0:00:01 (0.0997 s / it)
# Averaged stats: model_time: 0.0301 (0.0306)  evaluator_time: 0.0036 (0.0034)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.787
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.999
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.999
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.811
# Epoch: [3]  [ 0/48]  eta: 0:01:07  lr: 0.005000  loss: 0.0447 (0.0447)  loss_classifier: 0.0295 (0.0295)  loss_box_reg: 0.0115 (0.0115)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 1.4103  data: 1.1777  max mem: 958
# Epoch: [3]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0405 (0.0506)  loss_classifier: 0.0220 (0.0263)  loss_box_reg: 0.0130 (0.0184)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0051 (0.0054)  time: 0.0826  data: 0.0049  max mem: 958
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0410 (0.0491)  loss_classifier: 0.0226 (0.0259)  loss_box_reg: 0.0141 (0.0175)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 0.0832  data: 0.0058  max mem: 958
# Epoch: [3] Total time: 0:00:05 (0.1133 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0451 (0.0451)  evaluator_time: 0.0039 (0.0039)  time: 0.9086  data: 0.8565  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0308)  evaluator_time: 0.0036 (0.0033)  time: 0.0916  data: 0.0554  max mem: 958
# Test: Total time: 0:00:01 (0.0988 s / it)
# Averaged stats: model_time: 0.0301 (0.0308)  evaluator_time: 0.0036 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.834
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.834
# Epoch: [4]  [ 0/48]  eta: 0:01:09  lr: 0.005000  loss: 0.0315 (0.0315)  loss_classifier: 0.0169 (0.0169)  loss_box_reg: 0.0108 (0.0108)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 1.4432  data: 1.2592  max mem: 958
# Epoch: [4]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0390 (0.0382)  loss_classifier: 0.0195 (0.0201)  loss_box_reg: 0.0104 (0.0130)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0042 (0.0046)  time: 0.0830  data: 0.0044  max mem: 958
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0392 (0.0397)  loss_classifier: 0.0205 (0.0213)  loss_box_reg: 0.0111 (0.0132)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0044 (0.0047)  time: 0.0818  data: 0.0052  max mem: 958
# Epoch: [4] Total time: 0:00:05 (0.1136 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0465 (0.0465)  evaluator_time: 0.0044 (0.0044)  time: 0.9077  data: 0.8543  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0304)  evaluator_time: 0.0034 (0.0033)  time: 0.0910  data: 0.0555  max mem: 958
# Test: Total time: 0:00:01 (0.0984 s / it)
# Averaged stats: model_time: 0.0300 (0.0304)  evaluator_time: 0.0034 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.845
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.845
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
# Epoch: [5]  [ 0/48]  eta: 0:01:00  lr: 0.005000  loss: 0.0287 (0.0287)  loss_classifier: 0.0146 (0.0146)  loss_box_reg: 0.0105 (0.0105)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 1.2619  data: 0.9474  max mem: 958
# Epoch: [5]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0307 (0.0354)  loss_classifier: 0.0189 (0.0205)  loss_box_reg: 0.0100 (0.0102)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0040 (0.0042)  time: 0.0831  data: 0.0052  max mem: 958
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0314 (0.0369)  loss_classifier: 0.0196 (0.0216)  loss_box_reg: 0.0090 (0.0105)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 0.0831  data: 0.0055  max mem: 958
# Epoch: [5] Total time: 0:00:05 (0.1127 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0486 (0.0486)  evaluator_time: 0.0038 (0.0038)  time: 0.9111  data: 0.8563  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0313)  evaluator_time: 0.0033 (0.0033)  time: 0.0915  data: 0.0550  max mem: 958
# Test: Total time: 0:00:01 (0.0983 s / it)
# Averaged stats: model_time: 0.0301 (0.0313)  evaluator_time: 0.0033 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.879
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.895
# Epoch: [6]  [ 0/48]  eta: 0:01:08  lr: 0.005000  loss: 0.0273 (0.0273)  loss_classifier: 0.0153 (0.0153)  loss_box_reg: 0.0087 (0.0087)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.4291  data: 1.1392  max mem: 958
# Epoch: [6]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0281 (0.0332)  loss_classifier: 0.0169 (0.0186)  loss_box_reg: 0.0070 (0.0099)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0044)  time: 0.0896  data: 0.0124  max mem: 958
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0255 (0.0326)  loss_classifier: 0.0142 (0.0185)  loss_box_reg: 0.0067 (0.0095)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0038 (0.0044)  time: 0.0818  data: 0.0048  max mem: 958
# Epoch: [6] Total time: 0:00:05 (0.1186 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0460 (0.0460)  evaluator_time: 0.0037 (0.0037)  time: 0.9214  data: 0.8692  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0302 (0.0305)  evaluator_time: 0.0035 (0.0032)  time: 0.0916  data: 0.0559  max mem: 958
# Test: Total time: 0:00:01 (0.0981 s / it)
# Averaged stats: model_time: 0.0302 (0.0305)  evaluator_time: 0.0035 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.887
# Epoch: [7]  [ 0/48]  eta: 0:00:59  lr: 0.000500  loss: 0.0188 (0.0188)  loss_classifier: 0.0092 (0.0092)  loss_box_reg: 0.0068 (0.0068)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.2453  data: 0.9760  max mem: 958
# Epoch: [7]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0270 (0.0269)  loss_classifier: 0.0145 (0.0158)  loss_box_reg: 0.0065 (0.0069)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0036 (0.0041)  time: 0.0826  data: 0.0053  max mem: 958
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0227 (0.0270)  loss_classifier: 0.0133 (0.0155)  loss_box_reg: 0.0065 (0.0074)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0032 (0.0039)  time: 0.0827  data: 0.0053  max mem: 958
# Epoch: [7] Total time: 0:00:05 (0.1121 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0490 (0.0490)  evaluator_time: 0.0041 (0.0041)  time: 0.9248  data: 0.8692  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0303 (0.0311)  evaluator_time: 0.0034 (0.0035)  time: 0.0925  data: 0.0561  max mem: 958
# Test: Total time: 0:00:01 (0.0992 s / it)
# Averaged stats: model_time: 0.0303 (0.0311)  evaluator_time: 0.0034 (0.0035)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.920
# Epoch: [8]  [ 0/48]  eta: 0:01:02  lr: 0.000500  loss: 0.0149 (0.0149)  loss_classifier: 0.0077 (0.0077)  loss_box_reg: 0.0042 (0.0042)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.3121  data: 1.0677  max mem: 958
# Epoch: [8]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0211 (0.0249)  loss_classifier: 0.0128 (0.0153)  loss_box_reg: 0.0054 (0.0064)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0027 (0.0030)  time: 0.0830  data: 0.0051  max mem: 958
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0200 (0.0245)  loss_classifier: 0.0116 (0.0147)  loss_box_reg: 0.0047 (0.0065)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 0.0813  data: 0.0045  max mem: 958
# Epoch: [8] Total time: 0:00:05 (0.1139 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0473 (0.0473)  evaluator_time: 0.0046 (0.0046)  time: 0.9320  data: 0.8776  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0306)  evaluator_time: 0.0032 (0.0032)  time: 0.0910  data: 0.0553  max mem: 958
# Test: Total time: 0:00:01 (0.0988 s / it)
# Averaged stats: model_time: 0.0301 (0.0306)  evaluator_time: 0.0032 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.914
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.914
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.914
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.914
# Epoch: [9]  [ 0/48]  eta: 0:01:00  lr: 0.000500  loss: 0.0248 (0.0248)  loss_classifier: 0.0157 (0.0157)  loss_box_reg: 0.0068 (0.0068)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 1.2601  data: 1.0506  max mem: 958
# Epoch: [9]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0226 (0.0252)  loss_classifier: 0.0142 (0.0161)  loss_box_reg: 0.0058 (0.0061)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0031 (0.0029)  time: 0.0823  data: 0.0043  max mem: 958
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0188 (0.0248)  loss_classifier: 0.0117 (0.0152)  loss_box_reg: 0.0042 (0.0065)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0020 (0.0029)  time: 0.0827  data: 0.0045  max mem: 958
# Epoch: [9] Total time: 0:00:05 (0.1139 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0465 (0.0465)  evaluator_time: 0.0041 (0.0041)  time: 0.9303  data: 0.8771  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0305)  evaluator_time: 0.0031 (0.0031)  time: 0.0925  data: 0.0570  max mem: 958
# Test: Total time: 0:00:01 (0.0993 s / it)
# Averaged stats: model_time: 0.0300 (0.0305)  evaluator_time: 0.0031 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.911

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:34  model_time: 0.0493 (0.0493)  evaluator_time: 0.0056 (0.0056)  time: 2.0062  data: 1.9478  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0303 (0.0311)  evaluator_time: 0.0032 (0.0032)  time: 0.1560  data: 0.1198  max mem: 958
# Test: Total time: 0:00:03 (0.1780 s / it)
# Averaged stats: model_time: 0.0303 (0.0311)  evaluator_time: 0.0032 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.911

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 74,
#   'det_bboxes': [{Bbox object: [left=351, top=334, right=466, bottom=535] | <can> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/50.jpg} | score: 0.9997900128364563,
#    {Bbox object: [left=57, top=176, right=196, bottom=446] | <carton> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/50.jpg} | score: 0.9991766810417175,
#    {Bbox object: [left=53, top=412, right=368, bottom=518] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/50.jpg} | score: 0.9955980181694031]},
#  {'idx': 4,
#   'det_bboxes': [{Bbox object: [left=134, top=250, right=339, bottom=502] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/102.jpg} | score: 0.9695625901222229]},
#  {'idx': 49,
#   'det_bboxes': [{Bbox object: [left=119, top=112, right=243, bottom=426] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/28.jpg} | score: 0.9992658495903015,
#    {Bbox object: [left=288, top=241, right=403, bottom=442] | <can> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/28.jpg} | score: 0.9991744160652161,
#    {Bbox object: [left=81, top=403, right=472, bottom=546] | <milk_bottle> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/28.jpg} | score: 0.9935382008552551]},
#  {'idx': 56,
#   'det_bboxes': [{Bbox object: [left=187, top=270, right=285, bottom=451] | <can> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/34.jpg} | score: 0.9998106360435486,
#    {Bbox object: [left=77, top=146, right=180, bottom=394] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/34.jpg} | score: 0.9989796280860901,
#    {Bbox object: [left=339, top=222, right=469, bottom=548] | <milk_bottle> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/34.jpg} | score: 0.998640239238739]},
#  {'idx': 44,
#   'det_bboxes': [{Bbox object: [left=49, top=281, right=315, bottom=477] | <carton> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/23.jpg} | score: 0.9996651411056519,
#    {Bbox object: [left=250, top=324, right=461, bottom=507] | <milk_bottle> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/23.jpg} | score: 0.9974967837333679]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 33
# Number of test images: 33

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# PosixPath('/home/jiata/code/computervision/data/odFridgeObjects/images/41.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

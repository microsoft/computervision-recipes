# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0a0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['images', 'annotations', '.DS_Store']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)
# Out:
# [autoreload of utils_cv.detection.dataset failed: Traceback (most recent call last):
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 312, in update_instances
#     update_instances(old, new, obj.__dict__, visited)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 312, in update_instances
#     update_instances(old, new, obj.__dict__, visited)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 317, in update_instances
#     update_instances(old, new, obj, visited)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 317, in update_instances
#     update_instances(old, new, obj, visited)
#   File "/home/jiata/anaconda3/envs/cv/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 317, in update_instances
#     update_instances(old, new, obj, visited)
#   [Previous line repeated 1 more time]
# KeyboardInterrupt
# ]
# [<utils_cv.detection.references.transforms.ToTensor object at 0x7fa7adc289b0>]
# [<utils_cv.detection.references.transforms.ToTensor object at 0x7fa7adcf0208>, <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x7fa7adc28278>, ColorJitter(brightness=[0.8, 1.2], contrast=[0.8, 1.2], saturation=[0.6, 1.4], hue=[-0.05, 0.05])]
# ../../utils_cv/detection/dataset.py:65: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   os.path.join(anno_dir, root.find("path").text)

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7fa8219762e8>
# Testing dataset: 33 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7fa82185f9b0>

# %% [markdown]
# Lets visualize some of the images to make sure the annotation looks correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, the only required parameter is the dataset. The object will set the model to torchvision's Faster R-CNN using the default parameters. However, we can customize the model using the `get_pretrained_fasterrcnn` function and specifying the parameters we want.

# %%
model = get_pretrained_fasterrcnn(
    num_classes=len(data.labels) + 1, min_size=IM_SIZE, max_size=IM_SIZE
)

# %% [markdown]
# We can now pass our Detection Learner object the model.

# %%
detector = DetectionLearner(data, model=model)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:16  lr: 0.000111  loss: 1.5088 (1.5088)  loss_classifier: 1.3558 (1.3558)  loss_box_reg: 0.1487 (0.1487)  loss_objectness: 0.0004 (0.0004)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 2.8395  data: 0.5727  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:03  lr: 0.003300  loss: 0.5190 (0.7359)  loss_classifier: 0.2512 (0.4810)  loss_box_reg: 0.2501 (0.2404)  loss_objectness: 0.0039 (0.0078)  loss_rpn_box_reg: 0.0065 (0.0067)  time: 0.0800  data: 0.0022  max mem: 958
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3220 (0.5934)  loss_classifier: 0.1839 (0.3741)  loss_box_reg: 0.1539 (0.2064)  loss_objectness: 0.0008 (0.0055)  loss_rpn_box_reg: 0.0065 (0.0075)  time: 0.0827  data: 0.0050  max mem: 958
# Epoch: [0] Total time: 0:00:06 (0.1429 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:11  model_time: 0.0898 (0.0898)  evaluator_time: 0.0036 (0.0036)  time: 0.7008  data: 0.6037  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0394)  evaluator_time: 0.0036 (0.0036)  time: 0.0859  data: 0.0410  max mem: 958
# Test: Total time: 0:00:01 (0.0916 s / it)
# Averaged stats: model_time: 0.0299 (0.0394)  evaluator_time: 0.0036 (0.0036)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.493
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.809
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.605
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.569
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.659
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.659
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.659
# Epoch: [1]  [ 0/48]  eta: 0:00:40  lr: 0.005000  loss: 0.2255 (0.2255)  loss_classifier: 0.1559 (0.1559)  loss_box_reg: 0.0538 (0.0538)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0152 (0.0152)  time: 0.8345  data: 0.6763  max mem: 958
# Epoch: [1]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.1476 (0.1594)  loss_classifier: 0.0927 (0.1010)  loss_box_reg: 0.0417 (0.0466)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0091 (0.0108)  time: 0.0808  data: 0.0040  max mem: 958
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0947 (0.1396)  loss_classifier: 0.0512 (0.0866)  loss_box_reg: 0.0318 (0.0422)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0070 (0.0097)  time: 0.0808  data: 0.0044  max mem: 958
# Epoch: [1] Total time: 0:00:04 (0.1002 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:11  model_time: 0.0426 (0.0426)  evaluator_time: 0.0022 (0.0022)  time: 0.6485  data: 0.6012  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0307)  evaluator_time: 0.0031 (0.0031)  time: 0.0764  data: 0.0408  max mem: 958
# Test: Total time: 0:00:01 (0.0817 s / it)
# Averaged stats: model_time: 0.0299 (0.0307)  evaluator_time: 0.0031 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.736
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.973
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.937
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.781
# Epoch: [2]  [ 0/48]  eta: 0:00:40  lr: 0.005000  loss: 0.1139 (0.1139)  loss_classifier: 0.0698 (0.0698)  loss_box_reg: 0.0313 (0.0313)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0127 (0.0127)  time: 0.8408  data: 0.6826  max mem: 958
# Epoch: [2]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0675 (0.0729)  loss_classifier: 0.0374 (0.0395)  loss_box_reg: 0.0204 (0.0256)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 0.0796  data: 0.0028  max mem: 958
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0629 (0.0697)  loss_classifier: 0.0365 (0.0382)  loss_box_reg: 0.0184 (0.0239)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0059 (0.0066)  time: 0.0812  data: 0.0045  max mem: 958
# Epoch: [2] Total time: 0:00:04 (0.1002 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0436 (0.0436)  evaluator_time: 0.0023 (0.0023)  time: 0.6305  data: 0.5821  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0302)  evaluator_time: 0.0028 (0.0027)  time: 0.0739  data: 0.0393  max mem: 958
# Test: Total time: 0:00:01 (0.0795 s / it)
# Averaged stats: model_time: 0.0299 (0.0302)  evaluator_time: 0.0028 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.836
# Epoch: [3]  [ 0/48]  eta: 0:00:44  lr: 0.005000  loss: 0.1117 (0.1117)  loss_classifier: 0.0697 (0.0697)  loss_box_reg: 0.0346 (0.0346)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0070 (0.0070)  time: 0.9220  data: 0.6605  max mem: 958
# Epoch: [3]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0534 (0.0583)  loss_classifier: 0.0299 (0.0314)  loss_box_reg: 0.0189 (0.0205)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0062 (0.0060)  time: 0.0792  data: 0.0021  max mem: 958
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0403 (0.0538)  loss_classifier: 0.0207 (0.0286)  loss_box_reg: 0.0155 (0.0189)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0043 (0.0056)  time: 0.0811  data: 0.0049  max mem: 958
# Epoch: [3] Total time: 0:00:04 (0.1026 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:11  model_time: 0.0430 (0.0430)  evaluator_time: 0.0023 (0.0023)  time: 0.6611  data: 0.6133  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0307)  evaluator_time: 0.0027 (0.0026)  time: 0.0766  data: 0.0414  max mem: 958
# Test: Total time: 0:00:01 (0.0825 s / it)
# Averaged stats: model_time: 0.0300 (0.0307)  evaluator_time: 0.0027 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.856
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.887
# Epoch: [4]  [ 0/48]  eta: 0:00:40  lr: 0.005000  loss: 0.0303 (0.0303)  loss_classifier: 0.0168 (0.0168)  loss_box_reg: 0.0090 (0.0090)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.8365  data: 0.6935  max mem: 958
# Epoch: [4]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0492 (0.0481)  loss_classifier: 0.0267 (0.0268)  loss_box_reg: 0.0159 (0.0156)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0050 (0.0051)  time: 0.0812  data: 0.0034  max mem: 958
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0305 (0.0434)  loss_classifier: 0.0181 (0.0238)  loss_box_reg: 0.0117 (0.0144)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0032 (0.0047)  time: 0.0825  data: 0.0051  max mem: 958
# Epoch: [4] Total time: 0:00:04 (0.1007 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:11  model_time: 0.0419 (0.0419)  evaluator_time: 0.0022 (0.0022)  time: 0.6545  data: 0.6081  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0310)  evaluator_time: 0.0027 (0.0026)  time: 0.0759  data: 0.0404  max mem: 958
# Test: Total time: 0:00:01 (0.0815 s / it)
# Averaged stats: model_time: 0.0301 (0.0310)  evaluator_time: 0.0027 (0.0026)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.864
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.864
# Epoch: [5]  [ 0/48]  eta: 0:00:41  lr: 0.005000  loss: 0.0260 (0.0260)  loss_classifier: 0.0149 (0.0149)  loss_box_reg: 0.0084 (0.0084)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 0.8574  data: 0.6969  max mem: 958
# Epoch: [5]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0331 (0.0372)  loss_classifier: 0.0192 (0.0200)  loss_box_reg: 0.0112 (0.0125)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0044)  time: 0.0789  data: 0.0019  max mem: 958
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0319 (0.0372)  loss_classifier: 0.0191 (0.0205)  loss_box_reg: 0.0106 (0.0119)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0046)  time: 0.0817  data: 0.0048  max mem: 958
# Epoch: [5] Total time: 0:00:04 (0.1015 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0450 (0.0450)  evaluator_time: 0.0023 (0.0023)  time: 0.6343  data: 0.5845  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0308)  evaluator_time: 0.0025 (0.0025)  time: 0.0749  data: 0.0399  max mem: 958
# Test: Total time: 0:00:01 (0.0804 s / it)
# Averaged stats: model_time: 0.0300 (0.0308)  evaluator_time: 0.0025 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.879
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.906
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.906
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.906
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.906
# Epoch: [6]  [ 0/48]  eta: 0:00:42  lr: 0.005000  loss: 0.0103 (0.0103)  loss_classifier: 0.0054 (0.0054)  loss_box_reg: 0.0023 (0.0023)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 0.8897  data: 0.6587  max mem: 958
# Epoch: [6]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0300 (0.0296)  loss_classifier: 0.0169 (0.0166)  loss_box_reg: 0.0087 (0.0085)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0041 (0.0043)  time: 0.0834  data: 0.0045  max mem: 958
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0300 (0.0309)  loss_classifier: 0.0174 (0.0172)  loss_box_reg: 0.0075 (0.0090)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0039 (0.0043)  time: 0.0852  data: 0.0066  max mem: 958
# Epoch: [6] Total time: 0:00:05 (0.1045 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0413 (0.0413)  evaluator_time: 0.0019 (0.0019)  time: 0.8033  data: 0.7577  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0301)  evaluator_time: 0.0025 (0.0024)  time: 0.0837  data: 0.0493  max mem: 958
# Test: Total time: 0:00:01 (0.0896 s / it)
# Averaged stats: model_time: 0.0301 (0.0301)  evaluator_time: 0.0025 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.905
# Epoch: [7]  [ 0/48]  eta: 0:00:44  lr: 0.000500  loss: 0.0336 (0.0336)  loss_classifier: 0.0232 (0.0232)  loss_box_reg: 0.0075 (0.0075)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 0.9212  data: 0.7126  max mem: 958
# Epoch: [7]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0296 (0.0308)  loss_classifier: 0.0187 (0.0181)  loss_box_reg: 0.0067 (0.0085)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0037 (0.0038)  time: 0.0817  data: 0.0037  max mem: 958
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0222 (0.0278)  loss_classifier: 0.0144 (0.0166)  loss_box_reg: 0.0050 (0.0074)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0028 (0.0035)  time: 0.0818  data: 0.0044  max mem: 958
# Epoch: [7] Total time: 0:00:04 (0.1026 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0414 (0.0414)  evaluator_time: 0.0023 (0.0023)  time: 0.6465  data: 0.6001  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0300)  evaluator_time: 0.0025 (0.0024)  time: 0.0753  data: 0.0411  max mem: 958
# Test: Total time: 0:00:01 (0.0810 s / it)
# Averaged stats: model_time: 0.0299 (0.0300)  evaluator_time: 0.0025 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.894
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.921
# Epoch: [8]  [ 0/48]  eta: 0:00:40  lr: 0.000500  loss: 0.0271 (0.0271)  loss_classifier: 0.0112 (0.0112)  loss_box_reg: 0.0118 (0.0118)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 0.8446  data: 0.7001  max mem: 958
# Epoch: [8]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0220 (0.0233)  loss_classifier: 0.0126 (0.0143)  loss_box_reg: 0.0049 (0.0058)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0027 (0.0029)  time: 0.0809  data: 0.0039  max mem: 958
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0292 (0.0255)  loss_classifier: 0.0182 (0.0155)  loss_box_reg: 0.0068 (0.0066)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 0.0813  data: 0.0045  max mem: 958
# Epoch: [8] Total time: 0:00:04 (0.1005 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0435 (0.0435)  evaluator_time: 0.0023 (0.0023)  time: 0.6264  data: 0.5781  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0303)  evaluator_time: 0.0025 (0.0024)  time: 0.0732  data: 0.0388  max mem: 958
# Test: Total time: 0:00:01 (0.0795 s / it)
# Averaged stats: model_time: 0.0300 (0.0303)  evaluator_time: 0.0025 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.897
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.897
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.924
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.924
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.924
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.924
# Epoch: [9]  [ 0/48]  eta: 0:00:40  lr: 0.000500  loss: 0.0238 (0.0238)  loss_classifier: 0.0154 (0.0154)  loss_box_reg: 0.0051 (0.0051)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 0.8537  data: 0.6735  max mem: 958
# Epoch: [9]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0228 (0.0266)  loss_classifier: 0.0147 (0.0162)  loss_box_reg: 0.0051 (0.0068)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 0.0800  data: 0.0030  max mem: 958
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0226 (0.0256)  loss_classifier: 0.0145 (0.0157)  loss_box_reg: 0.0053 (0.0067)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0023 (0.0030)  time: 0.0814  data: 0.0051  max mem: 958
# Epoch: [9] Total time: 0:00:04 (0.1006 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0430 (0.0430)  evaluator_time: 0.0024 (0.0024)  time: 0.6227  data: 0.5746  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0301)  evaluator_time: 0.0025 (0.0024)  time: 0.0736  data: 0.0392  max mem: 958
# Test: Total time: 0:00:01 (0.0790 s / it)
# Averaged stats: model_time: 0.0299 (0.0301)  evaluator_time: 0.0025 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.895
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.919

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:10  model_time: 0.0417 (0.0417)  evaluator_time: 0.0022 (0.0022)  time: 0.6394  data: 0.5929  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0302)  evaluator_time: 0.0024 (0.0024)  time: 0.0747  data: 0.0404  max mem: 958
# Test: Total time: 0:00:01 (0.0805 s / it)
# Averaged stats: model_time: 0.0299 (0.0302)  evaluator_time: 0.0024 (0.0024)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.895
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.895
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.919
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.919

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 124,
#   'det_bboxes': [{Bbox object: [left=97, top=247, right=433, bottom=494] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/96.jpg} | score: 0.9996459484100342]},
#  {'idx': 51,
#   'det_bboxes': [{Bbox object: [left=258, top=219, right=381, bottom=458] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/3.jpg} | score: 0.9996429681777954]},
#  {'idx': 31,
#   'det_bboxes': [{Bbox object: [left=106, top=303, right=249, bottom=560] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/127.jpg} | score: 0.9995607733726501,
#    {Bbox object: [left=234, top=75, right=402, bottom=461] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/127.jpg} | score: 0.9990532994270325]},
#  {'idx': 64,
#   'det_bboxes': [{Bbox object: [left=134, top=172, right=223, bottom=413] | <milk_bottle> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/41.jpg} | score: 0.9993832111358643,
#    {Bbox object: [left=197, top=297, right=470, bottom=577] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/41.jpg} | score: 0.9993746876716614,
#    {Bbox object: [left=254, top=123, right=338, bottom=352] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/41.jpg} | score: 0.9987651109695435]},
#  {'idx': 19,
#   'det_bboxes': [{Bbox object: [left=65, top=164, right=181, bottom=476] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/116.jpg} | score: 0.9992971420288086,
#    {Bbox object: [left=248, top=109, right=420, bottom=529] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/116.jpg} | score: 0.9991145730018616]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 33
# Number of test images: 33

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# PosixPath('/home/jiata/code/computervision/data/odFridgeObjects/images/44.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

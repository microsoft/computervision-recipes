# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0a0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['images', 'annotations', '.DS_Store']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)
# Out:
# ../../utils_cv/detection/dataset.py:96: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   if root.find("path"):

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f88d4fa6518>
# Testing dataset: 33 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f88d4e8eda0>

# %% [markdown]
# Lets visualize some of the images to make sure the annotation looks correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, the only required parameter is the dataset. The object will set the model to torchvision's Faster R-CNN using the default parameters. However, we can customize the model using the `get_pretrained_fasterrcnn` function and specifying the parameters we want.

# %%
model = get_pretrained_fasterrcnn(
    num_classes=len(data.labels) + 1, min_size=IM_SIZE, max_size=IM_SIZE
)

# %% [markdown]
# We can now pass our Detection Learner object the model.

# %%
detector = DetectionLearner(data, model=model)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:35  lr: 0.000111  loss: 1.6547 (1.6547)  loss_classifier: 1.3815 (1.3815)  loss_box_reg: 0.2582 (0.2582)  loss_objectness: 0.0102 (0.0102)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 3.2477  data: 0.7902  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:03  lr: 0.003300  loss: 0.5042 (0.7315)  loss_classifier: 0.2486 (0.4840)  loss_box_reg: 0.2166 (0.2360)  loss_objectness: 0.0022 (0.0055)  loss_rpn_box_reg: 0.0049 (0.0059)  time: 0.0818  data: 0.0041  max mem: 958
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3434 (0.5960)  loss_classifier: 0.1699 (0.3762)  loss_box_reg: 0.1556 (0.2090)  loss_objectness: 0.0010 (0.0043)  loss_rpn_box_reg: 0.0072 (0.0065)  time: 0.0813  data: 0.0046  max mem: 958
# Epoch: [0] Total time: 0:00:07 (0.1513 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0914 (0.0914)  evaluator_time: 0.0048 (0.0048)  time: 0.8833  data: 0.7841  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0397)  evaluator_time: 0.0048 (0.0048)  time: 0.0981  data: 0.0516  max mem: 958
# Test: Total time: 0:00:01 (0.1046 s / it)
# Averaged stats: model_time: 0.0299 (0.0397)  evaluator_time: 0.0048 (0.0048)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.488
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.643
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.643
# Epoch: [1]  [ 0/48]  eta: 0:01:03  lr: 0.005000  loss: 0.2886 (0.2886)  loss_classifier: 0.1825 (0.1825)  loss_box_reg: 0.1008 (0.1008)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0052 (0.0052)  time: 1.3158  data: 1.1077  max mem: 958
# Epoch: [1]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.1436 (0.1879)  loss_classifier: 0.0905 (0.1164)  loss_box_reg: 0.0410 (0.0630)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0066 (0.0078)  time: 0.0821  data: 0.0056  max mem: 958
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.1148 (0.1625)  loss_classifier: 0.0741 (0.1010)  loss_box_reg: 0.0377 (0.0536)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0054 (0.0072)  time: 0.0811  data: 0.0049  max mem: 958
# Epoch: [1] Total time: 0:00:05 (0.1105 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.0432 (0.0432)  evaluator_time: 0.0036 (0.0036)  time: 0.9049  data: 0.8552  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0301)  evaluator_time: 0.0034 (0.0033)  time: 0.0895  data: 0.0543  max mem: 958
# Test: Total time: 0:00:01 (0.0962 s / it)
# Averaged stats: model_time: 0.0299 (0.0301)  evaluator_time: 0.0034 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.953
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.942
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.795
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
# Epoch: [2]  [ 0/48]  eta: 0:00:59  lr: 0.005000  loss: 0.1327 (0.1327)  loss_classifier: 0.0907 (0.0907)  loss_box_reg: 0.0330 (0.0330)  loss_objectness: 0.0015 (0.0015)  loss_rpn_box_reg: 0.0074 (0.0074)  time: 1.2386  data: 0.9632  max mem: 958
# Epoch: [2]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0747 (0.0852)  loss_classifier: 0.0470 (0.0540)  loss_box_reg: 0.0239 (0.0256)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0050 (0.0051)  time: 0.0821  data: 0.0042  max mem: 958
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0508 (0.0777)  loss_classifier: 0.0273 (0.0477)  loss_box_reg: 0.0150 (0.0241)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0039 (0.0051)  time: 0.0819  data: 0.0048  max mem: 958
# Epoch: [2] Total time: 0:00:05 (0.1121 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0469 (0.0469)  evaluator_time: 0.0037 (0.0037)  time: 0.8529  data: 0.7986  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0304)  evaluator_time: 0.0034 (0.0031)  time: 0.0879  data: 0.0525  max mem: 958
# Test: Total time: 0:00:01 (0.0942 s / it)
# Averaged stats: model_time: 0.0299 (0.0304)  evaluator_time: 0.0034 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.806
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.994
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.972
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.806
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.836
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.836
# Epoch: [3]  [ 0/48]  eta: 0:00:51  lr: 0.005000  loss: 0.0506 (0.0506)  loss_classifier: 0.0339 (0.0339)  loss_box_reg: 0.0134 (0.0134)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 1.0831  data: 0.9056  max mem: 958
# Epoch: [3]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0397 (0.0496)  loss_classifier: 0.0211 (0.0276)  loss_box_reg: 0.0131 (0.0166)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0040 (0.0050)  time: 0.0794  data: 0.0030  max mem: 958
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0428 (0.0501)  loss_classifier: 0.0233 (0.0292)  loss_box_reg: 0.0142 (0.0157)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0045 (0.0049)  time: 0.0806  data: 0.0043  max mem: 958
# Epoch: [3] Total time: 0:00:05 (0.1084 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0454 (0.0454)  evaluator_time: 0.0035 (0.0035)  time: 0.8736  data: 0.8210  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0303)  evaluator_time: 0.0032 (0.0030)  time: 0.0887  data: 0.0534  max mem: 958
# Test: Total time: 0:00:01 (0.0949 s / it)
# Averaged stats: model_time: 0.0299 (0.0303)  evaluator_time: 0.0032 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.841
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.841
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.841
# Epoch: [4]  [ 0/48]  eta: 0:00:58  lr: 0.005000  loss: 0.0840 (0.0840)  loss_classifier: 0.0450 (0.0450)  loss_box_reg: 0.0303 (0.0303)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0083 (0.0083)  time: 1.2224  data: 0.9551  max mem: 958
# Epoch: [4]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0375 (0.0470)  loss_classifier: 0.0199 (0.0264)  loss_box_reg: 0.0124 (0.0159)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0045)  time: 0.0815  data: 0.0049  max mem: 958
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0320 (0.0447)  loss_classifier: 0.0156 (0.0249)  loss_box_reg: 0.0099 (0.0148)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0047 (0.0046)  time: 0.0809  data: 0.0049  max mem: 958
# Epoch: [4] Total time: 0:00:05 (0.1107 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0433 (0.0433)  evaluator_time: 0.0042 (0.0042)  time: 0.8485  data: 0.7979  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0301)  evaluator_time: 0.0032 (0.0029)  time: 0.0873  data: 0.0524  max mem: 958
# Test: Total time: 0:00:01 (0.0944 s / it)
# Averaged stats: model_time: 0.0299 (0.0301)  evaluator_time: 0.0032 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.995
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.983
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.879
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.887
# Epoch: [5]  [ 0/48]  eta: 0:01:00  lr: 0.005000  loss: 0.0289 (0.0289)  loss_classifier: 0.0137 (0.0137)  loss_box_reg: 0.0104 (0.0104)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0030 (0.0030)  time: 1.2639  data: 0.9981  max mem: 958
# Epoch: [5]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0297 (0.0329)  loss_classifier: 0.0145 (0.0183)  loss_box_reg: 0.0085 (0.0099)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0044)  time: 0.0818  data: 0.0051  max mem: 958
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0316 (0.0364)  loss_classifier: 0.0176 (0.0202)  loss_box_reg: 0.0091 (0.0112)  loss_objectness: 0.0003 (0.0004)  loss_rpn_box_reg: 0.0043 (0.0046)  time: 0.0805  data: 0.0042  max mem: 958
# Epoch: [5] Total time: 0:00:05 (0.1108 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0440 (0.0440)  evaluator_time: 0.0034 (0.0034)  time: 0.8529  data: 0.8018  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0303)  evaluator_time: 0.0032 (0.0104)  time: 0.0954  data: 0.0527  max mem: 958
# Test: Total time: 0:00:01 (0.1023 s / it)
# Averaged stats: model_time: 0.0300 (0.0303)  evaluator_time: 0.0032 (0.0104)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.866
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.866
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.887
# Epoch: [6]  [ 0/48]  eta: 0:00:58  lr: 0.005000  loss: 0.0392 (0.0392)  loss_classifier: 0.0219 (0.0219)  loss_box_reg: 0.0114 (0.0114)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0052 (0.0052)  time: 1.2159  data: 1.0378  max mem: 958
# Epoch: [6]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0244 (0.0358)  loss_classifier: 0.0118 (0.0194)  loss_box_reg: 0.0076 (0.0116)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0041 (0.0042)  time: 0.0812  data: 0.0035  max mem: 958
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0310 (0.0337)  loss_classifier: 0.0161 (0.0185)  loss_box_reg: 0.0086 (0.0106)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 0.0815  data: 0.0047  max mem: 958
# Epoch: [6] Total time: 0:00:05 (0.1106 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0448 (0.0448)  evaluator_time: 0.0032 (0.0032)  time: 0.8508  data: 0.8002  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0307)  evaluator_time: 0.0032 (0.0030)  time: 0.0882  data: 0.0525  max mem: 958
# Test: Total time: 0:00:01 (0.0945 s / it)
# Averaged stats: model_time: 0.0300 (0.0307)  evaluator_time: 0.0032 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.858
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.873
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.873
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.873
# Epoch: [7]  [ 0/48]  eta: 0:01:05  lr: 0.000500  loss: 0.0293 (0.0293)  loss_classifier: 0.0153 (0.0153)  loss_box_reg: 0.0095 (0.0095)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 1.3721  data: 1.2297  max mem: 958
# Epoch: [7]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0280 (0.0294)  loss_classifier: 0.0181 (0.0177)  loss_box_reg: 0.0065 (0.0083)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0030 (0.0033)  time: 0.0812  data: 0.0045  max mem: 958
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0259 (0.0291)  loss_classifier: 0.0162 (0.0175)  loss_box_reg: 0.0058 (0.0082)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0024 (0.0033)  time: 0.0812  data: 0.0052  max mem: 958
# Epoch: [7] Total time: 0:00:05 (0.1103 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0527 (0.0527)  evaluator_time: 0.0032 (0.0032)  time: 0.8344  data: 0.7739  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0306)  evaluator_time: 0.0031 (0.0028)  time: 0.0863  data: 0.0509  max mem: 958
# Test: Total time: 0:00:01 (0.0932 s / it)
# Averaged stats: model_time: 0.0299 (0.0306)  evaluator_time: 0.0031 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.897
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.897
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.918
# Epoch: [8]  [ 0/48]  eta: 0:01:04  lr: 0.000500  loss: 0.0274 (0.0274)  loss_classifier: 0.0151 (0.0151)  loss_box_reg: 0.0086 (0.0086)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.3504  data: 1.0801  max mem: 958
# Epoch: [8]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0248 (0.0289)  loss_classifier: 0.0150 (0.0176)  loss_box_reg: 0.0057 (0.0077)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0031 (0.0033)  time: 0.0819  data: 0.0048  max mem: 958
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0212 (0.0264)  loss_classifier: 0.0141 (0.0162)  loss_box_reg: 0.0048 (0.0069)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0025 (0.0031)  time: 0.0813  data: 0.0052  max mem: 958
# Epoch: [8] Total time: 0:00:05 (0.1117 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0449 (0.0449)  evaluator_time: 0.0033 (0.0033)  time: 0.8393  data: 0.7883  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0302)  evaluator_time: 0.0032 (0.0028)  time: 0.0860  data: 0.0512  max mem: 958
# Test: Total time: 0:00:01 (0.0927 s / it)
# Averaged stats: model_time: 0.0299 (0.0302)  evaluator_time: 0.0032 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.909
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.997
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.909
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.928
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.928
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.928
# Epoch: [9]  [ 0/48]  eta: 0:01:01  lr: 0.000500  loss: 0.0177 (0.0177)  loss_classifier: 0.0116 (0.0116)  loss_box_reg: 0.0047 (0.0047)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 1.2748  data: 1.0005  max mem: 958
# Epoch: [9]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0215 (0.0251)  loss_classifier: 0.0139 (0.0154)  loss_box_reg: 0.0054 (0.0067)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0026 (0.0029)  time: 0.0805  data: 0.0033  max mem: 958
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0213 (0.0252)  loss_classifier: 0.0140 (0.0156)  loss_box_reg: 0.0051 (0.0066)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0026 (0.0029)  time: 0.0816  data: 0.0046  max mem: 958
# Epoch: [9] Total time: 0:00:05 (0.1111 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0452 (0.0452)  evaluator_time: 0.0034 (0.0034)  time: 0.8498  data: 0.7980  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0300 (0.0302)  evaluator_time: 0.0032 (0.0028)  time: 0.0871  data: 0.0521  max mem: 958
# Test: Total time: 0:00:01 (0.0937 s / it)
# Averaged stats: model_time: 0.0300 (0.0302)  evaluator_time: 0.0032 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.915
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.930

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:14  model_time: 0.0437 (0.0437)  evaluator_time: 0.0033 (0.0033)  time: 0.8300  data: 0.7787  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0299 (0.0302)  evaluator_time: 0.0031 (0.0028)  time: 0.0861  data: 0.0512  max mem: 958
# Test: Total time: 0:00:01 (0.0922 s / it)
# Averaged stats: model_time: 0.0299 (0.0302)  evaluator_time: 0.0031 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.915
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.930

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 60,
#   'det_bboxes': [{Bbox object: [left=25, top=199, right=201, bottom=556] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/38.jpg} | score: 0.999319314956665,
#    {Bbox object: [left=324, top=206, right=412, bottom=411] | <milk_bottle> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/38.jpg} | score: 0.9992284774780273,
#    {Bbox object: [left=190, top=334, right=411, bottom=512] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/38.jpg} | score: 0.9137900471687317,
#    {Bbox object: [left=200, top=335, right=408, bottom=506] | <milk_bottle> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/38.jpg} | score: 0.5700441598892212]},
#  {'idx': 5,
#   'det_bboxes': [{Bbox object: [left=136, top=253, right=314, bottom=431] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/103.jpg} | score: 0.9964593052864075]},
#  {'idx': 13,
#   'det_bboxes': [{Bbox object: [left=333, top=204, right=456, bottom=413] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/110.jpg} | score: 0.9984689354896545,
#    {Bbox object: [left=50, top=312, right=338, bottom=416] | <milk_bottle> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/110.jpg} | score: 0.9826281666755676]},
#  {'idx': 6,
#   'det_bboxes': [{Bbox object: [left=179, top=252, right=356, bottom=413] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/104.jpg} | score: 0.998198926448822]},
#  {'idx': 123,
#   'det_bboxes': [{Bbox object: [left=119, top=237, right=415, bottom=445] | <carton> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/95.jpg} | score: 0.999701201915741]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 33
# Number of test images: 33

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# PosixPath('/home/jiata/code/computervision/data/odFridgeObjects/images/84.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

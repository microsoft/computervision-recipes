# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0a0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500
SAVE_MODEL = True

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['models', 'images', 'annotations', '.DS_Store']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f1cb8f443c8>
# Testing dataset: 32 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f1cb8e33160>

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on /home/jiata/code/computervision/data/odFridgeObjects/images/85.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x7f1c4d5145c0>
# <utils_cv.detection.references.transforms.ToTensor object at 0x7f1c4d5145f8>
# <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x7f1c4d5146a0>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, the only required parameter is the dataset. The object will set the model to torchvision's Faster R-CNN using the default parameters. However, we can customize the model using the `get_pretrained_fasterrcnn` function and specifying the parameters we want.

# %%
model = get_pretrained_fasterrcnn(
    num_classes=len(data.labels) + 1, min_size=IM_SIZE, max_size=IM_SIZE
)

# %% [markdown]
# We can now pass our Detection Learner object the model.

# %%
detector = DetectionLearner(data, model=model)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:30  lr: 0.000111  loss: 2.2921 (2.2921)  loss_classifier: 2.0148 (2.0148)  loss_box_reg: 0.2685 (0.2685)  loss_objectness: 0.0060 (0.0060)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 3.1325  data: 0.8461  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:03  lr: 0.003300  loss: 0.5145 (0.8395)  loss_classifier: 0.2578 (0.5928)  loss_box_reg: 0.2225 (0.2343)  loss_objectness: 0.0055 (0.0061)  loss_rpn_box_reg: 0.0057 (0.0063)  time: 0.0805  data: 0.0030  max mem: 958
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3974 (0.6822)  loss_classifier: 0.2001 (0.4501)  loss_box_reg: 0.1882 (0.2195)  loss_objectness: 0.0020 (0.0061)  loss_rpn_box_reg: 0.0074 (0.0066)  time: 0.0822  data: 0.0053  max mem: 958
# Epoch: [0] Total time: 0:00:07 (0.1481 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:11  model_time: 0.0915 (0.0915)  evaluator_time: 0.0078 (0.0078)  time: 0.6918  data: 0.5900  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0300 (0.0339)  evaluator_time: 0.0055 (0.0055)  time: 0.0828  data: 0.0416  max mem: 958
# Test: Total time: 0:00:01 (0.0885 s / it)
# Averaged stats: model_time: 0.0300 (0.0339)  evaluator_time: 0.0055 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.405
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.712
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.405
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.604
# Epoch: [1]  [ 0/48]  eta: 0:00:47  lr: 0.005000  loss: 0.3627 (0.3627)  loss_classifier: 0.2000 (0.2000)  loss_box_reg: 0.1514 (0.1514)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0101 (0.0101)  time: 0.9852  data: 0.6998  max mem: 958
# Epoch: [1]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.1825 (0.1968)  loss_classifier: 0.1228 (0.1262)  loss_box_reg: 0.0429 (0.0607)  loss_objectness: 0.0003 (0.0025)  loss_rpn_box_reg: 0.0064 (0.0075)  time: 0.0816  data: 0.0045  max mem: 958
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.1635 (0.1867)  loss_classifier: 0.1013 (0.1196)  loss_box_reg: 0.0367 (0.0566)  loss_objectness: 0.0019 (0.0026)  loss_rpn_box_reg: 0.0080 (0.0079)  time: 0.0826  data: 0.0053  max mem: 958
# Epoch: [1] Total time: 0:00:05 (0.1053 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0455 (0.0455)  evaluator_time: 0.0042 (0.0042)  time: 0.6353  data: 0.5825  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0302 (0.0316)  evaluator_time: 0.0035 (0.0035)  time: 0.0788  data: 0.0418  max mem: 958
# Test: Total time: 0:00:01 (0.0845 s / it)
# Averaged stats: model_time: 0.0302 (0.0316)  evaluator_time: 0.0035 (0.0035)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.665
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.932
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.702
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
# Epoch: [2]  [ 0/48]  eta: 0:00:46  lr: 0.005000  loss: 0.0636 (0.0636)  loss_classifier: 0.0406 (0.0406)  loss_box_reg: 0.0183 (0.0183)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 0.9610  data: 0.6591  max mem: 958
# Epoch: [2]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0889 (0.0898)  loss_classifier: 0.0599 (0.0586)  loss_box_reg: 0.0227 (0.0246)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0053 (0.0060)  time: 0.0813  data: 0.0042  max mem: 958
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0646 (0.0845)  loss_classifier: 0.0374 (0.0539)  loss_box_reg: 0.0212 (0.0240)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0052 (0.0059)  time: 0.0810  data: 0.0041  max mem: 958
# Epoch: [2] Total time: 0:00:05 (0.1063 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0437 (0.0437)  evaluator_time: 0.0038 (0.0038)  time: 0.6501  data: 0.5997  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0301 (0.0315)  evaluator_time: 0.0035 (0.0033)  time: 0.0784  data: 0.0417  max mem: 958
# Test: Total time: 0:00:01 (0.0841 s / it)
# Averaged stats: model_time: 0.0301 (0.0315)  evaluator_time: 0.0035 (0.0033)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.779
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.812
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.812
# Epoch: [3]  [ 0/48]  eta: 0:00:44  lr: 0.005000  loss: 0.0486 (0.0486)  loss_classifier: 0.0285 (0.0285)  loss_box_reg: 0.0153 (0.0153)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 0.9371  data: 0.6928  max mem: 958
# Epoch: [3]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0460 (0.0529)  loss_classifier: 0.0215 (0.0279)  loss_box_reg: 0.0169 (0.0188)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0054 (0.0059)  time: 0.0814  data: 0.0035  max mem: 958
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0477 (0.0544)  loss_classifier: 0.0254 (0.0292)  loss_box_reg: 0.0153 (0.0190)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0047 (0.0058)  time: 0.0819  data: 0.0043  max mem: 958
# Epoch: [3] Total time: 0:00:05 (0.1064 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0431 (0.0431)  evaluator_time: 0.0034 (0.0034)  time: 0.6291  data: 0.5793  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0300 (0.0309)  evaluator_time: 0.0030 (0.0030)  time: 0.0769  data: 0.0412  max mem: 958
# Test: Total time: 0:00:01 (0.0834 s / it)
# Averaged stats: model_time: 0.0300 (0.0309)  evaluator_time: 0.0030 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.819
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.853
# Epoch: [4]  [ 0/48]  eta: 0:00:45  lr: 0.005000  loss: 0.0165 (0.0165)  loss_classifier: 0.0064 (0.0064)  loss_box_reg: 0.0075 (0.0075)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 0.9544  data: 0.7116  max mem: 958
# Epoch: [4]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0354 (0.0369)  loss_classifier: 0.0154 (0.0190)  loss_box_reg: 0.0139 (0.0126)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0044 (0.0050)  time: 0.0831  data: 0.0055  max mem: 958
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0352 (0.0381)  loss_classifier: 0.0187 (0.0197)  loss_box_reg: 0.0114 (0.0131)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0045 (0.0050)  time: 0.0818  data: 0.0051  max mem: 958
# Epoch: [4] Total time: 0:00:05 (0.1061 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0431 (0.0431)  evaluator_time: 0.0033 (0.0033)  time: 0.6266  data: 0.5769  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0301 (0.0310)  evaluator_time: 0.0027 (0.0028)  time: 0.0767  data: 0.0411  max mem: 958
# Test: Total time: 0:00:01 (0.0824 s / it)
# Averaged stats: model_time: 0.0301 (0.0310)  evaluator_time: 0.0027 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.817
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.968
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.849
# Epoch: [5]  [ 0/48]  eta: 0:00:48  lr: 0.005000  loss: 0.0499 (0.0499)  loss_classifier: 0.0255 (0.0255)  loss_box_reg: 0.0155 (0.0155)  loss_objectness: 0.0039 (0.0039)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 1.0158  data: 0.7547  max mem: 958
# Epoch: [5]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0280 (0.0343)  loss_classifier: 0.0154 (0.0185)  loss_box_reg: 0.0083 (0.0108)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0040 (0.0045)  time: 0.0807  data: 0.0032  max mem: 958
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0346 (0.0343)  loss_classifier: 0.0182 (0.0184)  loss_box_reg: 0.0106 (0.0108)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0042 (0.0046)  time: 0.0821  data: 0.0050  max mem: 958
# Epoch: [5] Total time: 0:00:05 (0.1065 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0412 (0.0412)  evaluator_time: 0.0034 (0.0034)  time: 0.6369  data: 0.5898  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0300 (0.0308)  evaluator_time: 0.0028 (0.0028)  time: 0.0845  data: 0.0490  max mem: 958
# Test: Total time: 0:00:01 (0.0902 s / it)
# Averaged stats: model_time: 0.0300 (0.0308)  evaluator_time: 0.0028 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.835
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.835
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# Epoch: [6]  [ 0/48]  eta: 0:00:53  lr: 0.005000  loss: 0.0382 (0.0382)  loss_classifier: 0.0194 (0.0194)  loss_box_reg: 0.0092 (0.0092)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0092 (0.0092)  time: 1.1110  data: 0.8348  max mem: 958
# Epoch: [6]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0218 (0.0303)  loss_classifier: 0.0119 (0.0157)  loss_box_reg: 0.0066 (0.0101)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0032 (0.0044)  time: 0.0812  data: 0.0039  max mem: 958
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0263 (0.0305)  loss_classifier: 0.0132 (0.0164)  loss_box_reg: 0.0066 (0.0097)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0037 (0.0043)  time: 0.0816  data: 0.0047  max mem: 958
# Epoch: [6] Total time: 0:00:05 (0.1061 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:09  model_time: 0.0442 (0.0442)  evaluator_time: 0.0035 (0.0035)  time: 0.6119  data: 0.5611  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0300 (0.0311)  evaluator_time: 0.0029 (0.0029)  time: 0.0764  data: 0.0405  max mem: 958
# Test: Total time: 0:00:01 (0.0820 s / it)
# Averaged stats: model_time: 0.0300 (0.0311)  evaluator_time: 0.0029 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.843
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.865
# Epoch: [7]  [ 0/48]  eta: 0:00:53  lr: 0.000500  loss: 0.0395 (0.0395)  loss_classifier: 0.0196 (0.0196)  loss_box_reg: 0.0139 (0.0139)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 1.1238  data: 0.8835  max mem: 958
# Epoch: [7]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0234 (0.0272)  loss_classifier: 0.0138 (0.0158)  loss_box_reg: 0.0064 (0.0075)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0036 (0.0038)  time: 0.0811  data: 0.0037  max mem: 958
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0225 (0.0261)  loss_classifier: 0.0144 (0.0153)  loss_box_reg: 0.0053 (0.0071)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0026 (0.0035)  time: 0.0818  data: 0.0046  max mem: 958
# Epoch: [7] Total time: 0:00:05 (0.1065 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0433 (0.0433)  evaluator_time: 0.0035 (0.0035)  time: 0.6309  data: 0.5816  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0301 (0.0309)  evaluator_time: 0.0027 (0.0028)  time: 0.0763  data: 0.0408  max mem: 958
# Test: Total time: 0:00:01 (0.0823 s / it)
# Averaged stats: model_time: 0.0301 (0.0309)  evaluator_time: 0.0027 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.879
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.905
# Epoch: [8]  [ 0/48]  eta: 0:00:47  lr: 0.000500  loss: 0.0194 (0.0194)  loss_classifier: 0.0114 (0.0114)  loss_box_reg: 0.0040 (0.0040)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 0.9948  data: 0.7554  max mem: 958
# Epoch: [8]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0247 (0.0251)  loss_classifier: 0.0136 (0.0153)  loss_box_reg: 0.0059 (0.0066)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0033 (0.0029)  time: 0.0809  data: 0.0036  max mem: 958
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0244 (0.0253)  loss_classifier: 0.0138 (0.0153)  loss_box_reg: 0.0054 (0.0066)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0033 (0.0031)  time: 0.0815  data: 0.0042  max mem: 958
# Epoch: [8] Total time: 0:00:05 (0.1054 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:09  model_time: 0.0467 (0.0467)  evaluator_time: 0.0037 (0.0037)  time: 0.6215  data: 0.5679  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0301 (0.0311)  evaluator_time: 0.0028 (0.0028)  time: 0.0768  data: 0.0410  max mem: 958
# Test: Total time: 0:00:01 (0.0821 s / it)
# Averaged stats: model_time: 0.0301 (0.0311)  evaluator_time: 0.0028 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.870
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.897
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.897
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.897
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.897
# Epoch: [9]  [ 0/48]  eta: 0:00:51  lr: 0.000500  loss: 0.0339 (0.0339)  loss_classifier: 0.0191 (0.0191)  loss_box_reg: 0.0118 (0.0118)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.0722  data: 0.8792  max mem: 958
# Epoch: [9]  [30/48]  eta: 0:00:02  lr: 0.000500  loss: 0.0201 (0.0231)  loss_classifier: 0.0121 (0.0139)  loss_box_reg: 0.0052 (0.0062)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0022 (0.0028)  time: 0.0811  data: 0.0038  max mem: 958
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0231 (0.0232)  loss_classifier: 0.0134 (0.0139)  loss_box_reg: 0.0057 (0.0062)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0030 (0.0029)  time: 0.0812  data: 0.0047  max mem: 958
# Epoch: [9] Total time: 0:00:05 (0.1056 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0429 (0.0429)  evaluator_time: 0.0034 (0.0034)  time: 0.6623  data: 0.6136  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0302 (0.0312)  evaluator_time: 0.0028 (0.0028)  time: 0.0780  data: 0.0422  max mem: 958
# Test: Total time: 0:00:01 (0.0837 s / it)
# Averaged stats: model_time: 0.0302 (0.0312)  evaluator_time: 0.0028 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.898

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:10  model_time: 0.0417 (0.0417)  evaluator_time: 0.0034 (0.0034)  time: 0.6422  data: 0.5948  max mem: 958
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0301 (0.0308)  evaluator_time: 0.0027 (0.0027)  time: 0.0765  data: 0.0411  max mem: 958
# Test: Total time: 0:00:01 (0.0820 s / it)
# Averaged stats: model_time: 0.0301 (0.0308)  evaluator_time: 0.0027 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.980
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.898
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.898

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 124,
#   'det_bboxes': [{Bbox object: [left=88, top=240, right=427, bottom=490] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/96.jpg} | score: 0.9995148181915283]},
#  {'idx': 119,
#   'det_bboxes': [{Bbox object: [left=306, top=204, right=413, bottom=401] | <milk_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/91.jpg} | score: 0.9994008541107178,
#    {Bbox object: [left=214, top=280, right=312, bottom=398] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/91.jpg} | score: 0.9991331696510315,
#    {Bbox object: [left=110, top=171, right=225, bottom=410] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/91.jpg} | score: 0.9979990124702454,
#    {Bbox object: [left=81, top=383, right=452, bottom=557] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/91.jpg} | score: 0.9950395226478577]},
#  {'idx': 112,
#   'det_bboxes': [{Bbox object: [left=372, top=322, right=474, bottom=493] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/85.jpg} | score: 0.9994022846221924,
#    {Bbox object: [left=291, top=246, right=379, bottom=482] | <milk_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/85.jpg} | score: 0.9981030225753784,
#    {Bbox object: [left=44, top=197, right=231, bottom=471] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/85.jpg} | score: 0.992708683013916,
#    {Bbox object: [left=212, top=201, right=302, bottom=491] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/85.jpg} | score: 0.9847486615180969]},
#  {'idx': 123,
#   'det_bboxes': [{Bbox object: [left=108, top=231, right=408, bottom=448] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/95.jpg} | score: 0.9994841814041138]},
#  {'idx': 121,
#   'det_bboxes': [{Bbox object: [left=224, top=284, right=346, bottom=493] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/93.jpg} | score: 0.9986473917961121,
#    {Bbox object: [left=106, top=158, right=234, bottom=492] | <water_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/93.jpg} | score: 0.9986003041267395,
#    {Bbox object: [left=306, top=157, right=393, bottom=308] | <milk_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/93.jpg} | score: 0.9980689883232117,
#    {Bbox object: [left=207, top=291, right=398, bottom=451] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/93.jpg} | score: 0.865105390548706]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 32
# Number of test images: 32

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# PosixPath('/home/jiata/code/computervision/data/odFridgeObjects/images/13.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ## Save the model
# The final step is to save the model to disk. We'll do this since the deployment notebook will deploy this model.

# %%
if SAVE_MODEL:
    detector.save("my_drink_detector2")

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.classification.data import Urls as UrlsIC
from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset, get_transform
from utils_cv.detection.plot import (
    display_bboxes_mask,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_counts_curves,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import (
    DetectionLearner,
    get_pretrained_fasterrcnn,
)
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend("TkAgg")

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
NEG_DATA_PATH = unzip_url(UrlsIC.fridge_objects_negatives_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500
SAVE_MODEL = True

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['.DS_Store', 'annotations', 'images', 'models']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x000001A0B79D2F28>
# Testing dataset: 32 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x000001A0C5C5A1D0>

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\126.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x000001A0C58EEC50>
# <utils_cv.detection.references.transforms.ToTensor object at 0x000001A0C58EECF8>
# <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x000001A0C5946780>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, we can pass in the dataset. By default, the object will set the model to torchvision's Faster R-CNN. Alternatively, we can pass in the model we want to use - we would customize the model using the `get_pretrained_fasterrcnn` function and specify the parameters we want.

# %%
detector = DetectionLearner(data, im_size=IM_SIZE)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:14  lr: 0.000111  loss: 2.2412 (2.2412)  loss_classifier: 1.9721 (1.9721)  loss_box_reg: 0.2560 (0.2560)  loss_objectness: 0.0059 (0.0059)  loss_rpn_box_reg: 0.0072 (0.0072)  time: 2.8095  data: 0.2500  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:05  lr: 0.003300  loss: 0.5104 (0.8288)  loss_classifier: 0.2456 (0.5877)  loss_box_reg: 0.2193 (0.2279)  loss_objectness: 0.0057 (0.0070)  loss_rpn_box_reg: 0.0060 (0.0062)  time: 0.1997  data: 0.1063  max mem: 960
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3529 (0.6648)  loss_classifier: 0.1831 (0.4489)  loss_box_reg: 0.1671 (0.2036)  loss_objectness: 0.0022 (0.0054)  loss_rpn_box_reg: 0.0067 (0.0070)  time: 0.1963  data: 0.1017  max mem: 960
# Epoch: [0] Total time: 0:00:12 (0.2521 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:02  model_time: 0.1094 (0.1094)  evaluator_time: 0.0156 (0.0156)  time: 0.1406  data: 0.0156  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0365)  evaluator_time: 0.0000 (0.0078)  time: 0.0703  data: 0.0250  max mem: 960
# Test: Total time: 0:00:01 (0.0703 s / it)
# Averaged stats: model_time: 0.0312 (0.0365)  evaluator_time: 0.0000 (0.0078)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.628
# Epoch: [1]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.3204 (0.3204)  loss_classifier: 0.1685 (0.1685)  loss_box_reg: 0.1413 (0.1413)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0100 (0.0100)  time: 0.2031  data: 0.1094  max mem: 960
# Epoch: [1]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.1369 (0.1651)  loss_classifier: 0.0871 (0.1047)  loss_box_reg: 0.0372 (0.0508)  loss_objectness: 0.0005 (0.0016)  loss_rpn_box_reg: 0.0074 (0.0080)  time: 0.1973  data: 0.1025  max mem: 960
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.1116 (0.1403)  loss_classifier: 0.0654 (0.0881)  loss_box_reg: 0.0299 (0.0427)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0078 (0.0083)  time: 0.1965  data: 0.1042  max mem: 960
# Epoch: [1] Total time: 0:00:09 (0.1988 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0313 (0.0313)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0312  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0372)  evaluator_time: 0.0000 (0.0039)  time: 0.0674  data: 0.0254  max mem: 960
# Test: Total time: 0:00:01 (0.0674 s / it)
# Averaged stats: model_time: 0.0312 (0.0372)  evaluator_time: 0.0000 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.960
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.816
# Epoch: [2]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0602 (0.0602)  loss_classifier: 0.0344 (0.0344)  loss_box_reg: 0.0177 (0.0177)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0073 (0.0073)  time: 0.2031  data: 0.1094  max mem: 960
# Epoch: [2]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0706 (0.0796)  loss_classifier: 0.0388 (0.0449)  loss_box_reg: 0.0230 (0.0267)  loss_objectness: 0.0003 (0.0014)  loss_rpn_box_reg: 0.0049 (0.0067)  time: 0.1960  data: 0.1024  max mem: 960
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0472 (0.0727)  loss_classifier: 0.0269 (0.0415)  loss_box_reg: 0.0144 (0.0236)  loss_objectness: 0.0002 (0.0012)  loss_rpn_box_reg: 0.0051 (0.0065)  time: 0.1974  data: 0.1056  max mem: 960
# Epoch: [2] Total time: 0:00:09 (0.1981 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0313  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0020)  time: 0.0693  data: 0.0322  max mem: 960
# Test: Total time: 0:00:01 (0.0693 s / it)
# Averaged stats: model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.825
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.843
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.843
# Epoch: [3]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0591 (0.0591)  loss_classifier: 0.0367 (0.0367)  loss_box_reg: 0.0136 (0.0136)  loss_objectness: 0.0014 (0.0014)  loss_rpn_box_reg: 0.0074 (0.0074)  time: 0.2031  data: 0.1094  max mem: 960
# Epoch: [3]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0527 (0.0522)  loss_classifier: 0.0275 (0.0292)  loss_box_reg: 0.0182 (0.0174)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0049 (0.0052)  time: 0.2046  data: 0.1089  max mem: 960
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0435 (0.0500)  loss_classifier: 0.0230 (0.0269)  loss_box_reg: 0.0153 (0.0168)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0056 (0.0057)  time: 0.1975  data: 0.1032  max mem: 960
# Epoch: [3] Total time: 0:00:09 (0.2030 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0313  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0345)  evaluator_time: 0.0000 (0.0002)  time: 0.0625  data: 0.0268  max mem: 960
# Test: Total time: 0:00:01 (0.0625 s / it)
# Averaged stats: model_time: 0.0312 (0.0345)  evaluator_time: 0.0000 (0.0002)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.847
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.867
# Epoch: [4]  [ 0/48]  eta: 0:00:10  lr: 0.005000  loss: 0.0280 (0.0280)  loss_classifier: 0.0144 (0.0144)  loss_box_reg: 0.0083 (0.0083)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0051 (0.0051)  time: 0.2115  data: 0.1094  max mem: 960
# Epoch: [4]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0385 (0.0412)  loss_classifier: 0.0212 (0.0228)  loss_box_reg: 0.0123 (0.0133)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0041 (0.0048)  time: 0.1933  data: 0.1011  max mem: 960
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0457 (0.0420)  loss_classifier: 0.0253 (0.0227)  loss_box_reg: 0.0141 (0.0138)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0047 (0.0051)  time: 0.1929  data: 0.0990  max mem: 960
# Epoch: [4] Total time: 0:00:09 (0.1971 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0156 (0.0156)  time: 0.0625  data: 0.0156  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0049)  time: 0.0645  data: 0.0235  max mem: 960
# Test: Total time: 0:00:01 (0.0645 s / it)
# Averaged stats: model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.820
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.846
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.846
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.846
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.846
# Epoch: [5]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0434 (0.0434)  loss_classifier: 0.0175 (0.0175)  loss_box_reg: 0.0158 (0.0158)  loss_objectness: 0.0007 (0.0007)  loss_rpn_box_reg: 0.0094 (0.0094)  time: 0.1888  data: 0.0937  max mem: 960
# Epoch: [5]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0347 (0.0400)  loss_classifier: 0.0188 (0.0203)  loss_box_reg: 0.0131 (0.0147)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0039 (0.0048)  time: 0.1996  data: 0.0996  max mem: 960
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0303 (0.0387)  loss_classifier: 0.0160 (0.0196)  loss_box_reg: 0.0112 (0.0141)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0038 (0.0048)  time: 0.1905  data: 0.0973  max mem: 960
# Epoch: [5] Total time: 0:00:09 (0.1943 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0312 (0.0312)  evaluator_time: 0.0156 (0.0156)  time: 0.0781  data: 0.0313  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0332)  evaluator_time: 0.0000 (0.0068)  time: 0.0646  data: 0.0236  max mem: 960
# Test: Total time: 0:00:01 (0.0646 s / it)
# Averaged stats: model_time: 0.0312 (0.0332)  evaluator_time: 0.0000 (0.0068)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.855
# Epoch: [6]  [ 0/48]  eta: 0:00:08  lr: 0.005000  loss: 0.0389 (0.0389)  loss_classifier: 0.0206 (0.0206)  loss_box_reg: 0.0139 (0.0139)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.1875  data: 0.0937  max mem: 960
# Epoch: [6]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0338 (0.0363)  loss_classifier: 0.0184 (0.0188)  loss_box_reg: 0.0095 (0.0119)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0047 (0.0053)  time: 0.1870  data: 0.0957  max mem: 960
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0338 (0.0353)  loss_classifier: 0.0177 (0.0184)  loss_box_reg: 0.0093 (0.0114)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0040 (0.0051)  time: 0.1902  data: 0.1006  max mem: 960
# Epoch: [6] Total time: 0:00:09 (0.1899 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0312  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0343)  evaluator_time: 0.0000 (0.0000)  time: 0.0636  data: 0.0244  max mem: 960
# Test: Total time: 0:00:01 (0.0636 s / it)
# Averaged stats: model_time: 0.0312 (0.0343)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.853
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.874
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.874
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.874
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.874
# Epoch: [7]  [ 0/48]  eta: 0:00:09  lr: 0.000500  loss: 0.0390 (0.0390)  loss_classifier: 0.0244 (0.0244)  loss_box_reg: 0.0104 (0.0104)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 0.2031  data: 0.1094  max mem: 960
# Epoch: [7]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0282 (0.0319)  loss_classifier: 0.0154 (0.0176)  loss_box_reg: 0.0074 (0.0092)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0035 (0.0048)  time: 0.1899  data: 0.0977  max mem: 960
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0222 (0.0292)  loss_classifier: 0.0134 (0.0163)  loss_box_reg: 0.0062 (0.0084)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0028 (0.0042)  time: 0.1932  data: 0.1002  max mem: 960
# Epoch: [7] Total time: 0:00:09 (0.1923 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0312 (0.0312)  evaluator_time: 0.0156 (0.0156)  time: 0.0781  data: 0.0312  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0327)  evaluator_time: 0.0000 (0.0012)  time: 0.0655  data: 0.0317  max mem: 960
# Test: Total time: 0:00:01 (0.0655 s / it)
# Averaged stats: model_time: 0.0312 (0.0327)  evaluator_time: 0.0000 (0.0012)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.884
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.904
# Epoch: [8]  [ 0/48]  eta: 0:00:08  lr: 0.000500  loss: 0.0329 (0.0329)  loss_classifier: 0.0199 (0.0199)  loss_box_reg: 0.0096 (0.0096)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 0.1875  data: 0.0937  max mem: 960
# Epoch: [8]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0247 (0.0277)  loss_classifier: 0.0165 (0.0168)  loss_box_reg: 0.0068 (0.0073)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0033 (0.0033)  time: 0.1933  data: 0.1030  max mem: 960
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0219 (0.0275)  loss_classifier: 0.0140 (0.0168)  loss_box_reg: 0.0056 (0.0072)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 0.1922  data: 0.1001  max mem: 960
# Epoch: [8] Total time: 0:00:09 (0.1930 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0313 (0.0313)  evaluator_time: 0.0000 (0.0000)  time: 0.0636  data: 0.0323  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0040)  time: 0.0626  data: 0.0245  max mem: 960
# Test: Total time: 0:00:01 (0.0636 s / it)
# Averaged stats: model_time: 0.0312 (0.0342)  evaluator_time: 0.0000 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.886
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.903
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.903
# Epoch: [9]  [ 0/48]  eta: 0:00:09  lr: 0.000500  loss: 0.0231 (0.0231)  loss_classifier: 0.0134 (0.0134)  loss_box_reg: 0.0056 (0.0056)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 0.1883  data: 0.0946  max mem: 960
# Epoch: [9]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0223 (0.0256)  loss_classifier: 0.0135 (0.0152)  loss_box_reg: 0.0054 (0.0069)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0024 (0.0032)  time: 0.1890  data: 0.0982  max mem: 960
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0211 (0.0253)  loss_classifier: 0.0136 (0.0155)  loss_box_reg: 0.0051 (0.0065)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0024 (0.0031)  time: 0.1910  data: 0.0986  max mem: 960
# Epoch: [9] Total time: 0:00:09 (0.1892 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0156  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0320)  evaluator_time: 0.0000 (0.0000)  time: 0.0624  data: 0.0303  max mem: 960
# Test: Total time: 0:00:00 (0.0624 s / it)
# Averaged stats: model_time: 0.0312 (0.0320)  evaluator_time: 0.0000 (0.0000)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.886
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.904

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0465 (0.0465)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0160  max mem: 960
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0343)  evaluator_time: 0.0000 (0.0021)  time: 0.0628  data: 0.0225  max mem: 960
# Test: Total time: 0:00:01 (0.0630 s / it)
# Averaged stats: model_time: 0.0312 (0.0343)  evaluator_time: 0.0000 (0.0021)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.886
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.904

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# Precision-Recall curves can be hard to interpret, and hence we also provide counts how many (left) images have at least one wrong detection / missed ground truth; and (right) the total number of wrong detections / missed ground truths summed over all images. These counts are shown for different detection score thresholds, ie. effectly discarding detections with confidence score lower than a given thresholds.
#
# As can be seen, the model performs well on the test dataset for thresholds between 0.5 and 0.9, but especially at a threshold of 0.5 over-fires on the negative images (images which do not contain any of the objects) since similar images were not included in the training set. This information is especially valuable when deciding on a precision-recall operating point. To avoid over-firing, one can either add more images to the training set directly or via hard-negative mining as explained in the [12_hard_negative_sampling.ipynb](12_hard_negative_sampling.ipynb) notebook.

# %%
# Run detector on the test images. Set threshold to 0 to keep all low confidence detections.
print(f"Running detector on {len(data.test_ds)} test images...")
detections = detector.predict_dl(data.test_dl, threshold=0)

# Run detector on the negative images
if NEG_DATA_PATH is None or NEG_DATA_PATH == "":
    detections_neg = None
else:
    neg_data = DetectionDataset(
        NEG_DATA_PATH,
        train_pct=1.0,  # , batch_size=BATCH_SIZE,
        im_dir="",
        allow_negatives=True,
        train_transforms=get_transform(train=False),
    )
    print(f"Running detector on {len(neg_data.train_ds)} negative images...")
    detections_neg = detector.predict_dl(neg_data.train_dl, threshold=0)

# Count and plot number of wrong/missing detections
plot_counts_curves(detections, data.test_ds, detections_neg)
# Out:
# Running detector on 32 test images...
# Running detector on 64 negative images...

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 115,
#   'det_bboxes': [{Bbox object: [left=288, top=303, right=379, bottom=464] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\88.jpg} | score: 0.9993022680282593,
#    {Bbox object: [left=27, top=256, right=137, bottom=516] | <milk_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\88.jpg} | score: 0.9990540146827698,
#    {Bbox object: [left=363, top=205, right=461, bottom=451] | <water_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\88.jpg} | score: 0.9915173053741455,
#    {Bbox object: [left=103, top=238, right=320, bottom=479] | <carton> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\88.jpg} | score: 0.985773503780365]},
#  {'idx': 45,
#   'det_bboxes': [{Bbox object: [left=141, top=158, right=268, bottom=516] | <water_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\24.jpg} | score: 0.9973946809768677,
#    {Bbox object: [left=244, top=189, right=341, bottom=481] | <milk_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\24.jpg} | score: 0.9959957599639893]},
#  {'idx': 37,
#   'det_bboxes': [{Bbox object: [left=95, top=151, right=223, bottom=496] | <water_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\17.jpg} | score: 0.9981448650360107,
#    {Bbox object: [left=221, top=189, right=338, bottom=505] | <milk_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\17.jpg} | score: 0.9961052536964417]},
#  {'idx': 15,
#   'det_bboxes': [{Bbox object: [left=265, top=146, right=434, bottom=513] | <carton> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\112.jpg} | score: 0.9983299374580383,
#    {Bbox object: [left=32, top=416, right=366, bottom=531] | <water_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\112.jpg} | score: 0.9903586506843567]},
#  {'idx': 35,
#   'det_bboxes': [{Bbox object: [left=287, top=246, right=426, bottom=496] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\15.jpg} | score: 0.9986236095428467,
#    {Bbox object: [left=97, top=151, right=221, bottom=474] | <milk_bottle> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\15.jpg} | score: 0.9983572363853455]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(
    f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}"
)
# Out:
# Number of detections: 32
# Number of test images: 32

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# WindowsPath('C:/Users/pabuehle/Desktop/ComputerVision/data/odFridgeObjects/images/64.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes_mask(detections, new_im_path, plot_settings=plot_settings)

# %% [markdown]
# ## Save the model
# The final step is to save the model to disk. We'll do this since the deployment notebook will deploy this model.

# %%
if SAVE_MODEL:
    detector.save("my_drink_detector")
# Out:
# Model is saved to C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\models\my_drink_detector

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

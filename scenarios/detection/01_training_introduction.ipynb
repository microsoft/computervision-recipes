# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.classification.data import Urls as UrlsIC
from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset, get_transform
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_counts_curves,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
NEG_DATA_PATH = unzip_url(UrlsIC.fridge_objects_negatives_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500
SAVE_MODEL = True

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['.DS_Store', 'annotations', 'images', 'models']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x0000022517BDAE48>
# Testing dataset: 32 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x000002252140B320>

# %% [markdown]
# By default, we apply some image transformations to the training set. Lets see how the transformations look:

# %%
data.train_ds.dataset.show_im_transformations()
# Out:
# Transformations applied on C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\121.jpg:
# <utils_cv.detection.dataset.ColorJitterTransform object at 0x000002251B02FCC0>
# <utils_cv.detection.references.transforms.ToTensor object at 0x000002251B02FD68>
# <utils_cv.detection.references.transforms.RandomHorizontalFlip object at 0x000002251B0C56D8>

# %% [markdown]
# Lets visualize the annotations to make sure they look correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, we can pass in the dataset. By default, the object will set the model to torchvision's Faster R-CNN. Alternatively, we can pass in the model we want to use - we would customize the model using the `get_pretrained_fasterrcnn` function and specify the parameters we want.

# %%
detector = DetectionLearner(data, im_size=IM_SIZE)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:06  lr: 0.000111  loss: 2.1635 (2.1635)  loss_classifier: 1.9046 (1.9046)  loss_box_reg: 0.2520 (0.2520)  loss_objectness: 0.0023 (0.0023)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 2.6421  data: 0.1094  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:04  lr: 0.003300  loss: 0.5243 (0.8194)  loss_classifier: 0.2498 (0.5880)  loss_box_reg: 0.2142 (0.2197)  loss_objectness: 0.0040 (0.0057)  loss_rpn_box_reg: 0.0050 (0.0059)  time: 0.1945  data: 0.1031  max mem: 959
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3728 (0.6666)  loss_classifier: 0.1866 (0.4484)  loss_box_reg: 0.1736 (0.2073)  loss_objectness: 0.0015 (0.0044)  loss_rpn_box_reg: 0.0077 (0.0064)  time: 0.1966  data: 0.1038  max mem: 959
# Epoch: [0] Total time: 0:00:11 (0.2471 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:02  model_time: 0.0937 (0.0937)  evaluator_time: 0.0156 (0.0156)  time: 0.1406  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0391)  evaluator_time: 0.0000 (0.0030)  time: 0.0704  data: 0.0273  max mem: 959
# Test: Total time: 0:00:01 (0.0704 s / it)
# Averaged stats: model_time: 0.0312 (0.0391)  evaluator_time: 0.0000 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.729
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.389
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.424
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
# Epoch: [1]  [ 0/48]  eta: 0:00:08  lr: 0.005000  loss: 0.3572 (0.3572)  loss_classifier: 0.2012 (0.2012)  loss_box_reg: 0.1371 (0.1371)  loss_objectness: 0.0034 (0.0034)  loss_rpn_box_reg: 0.0155 (0.0155)  time: 0.1874  data: 0.0937  max mem: 959
# Epoch: [1]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.1392 (0.1855)  loss_classifier: 0.0896 (0.1188)  loss_box_reg: 0.0385 (0.0556)  loss_objectness: 0.0003 (0.0015)  loss_rpn_box_reg: 0.0074 (0.0096)  time: 0.2043  data: 0.1129  max mem: 959
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0918 (0.1570)  loss_classifier: 0.0501 (0.0975)  loss_box_reg: 0.0348 (0.0497)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0063 (0.0085)  time: 0.2258  data: 0.1321  max mem: 959
# Epoch: [1] Total time: 0:00:10 (0.2089 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0781  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0313 (0.0352)  evaluator_time: 0.0000 (0.0059)  time: 0.0665  data: 0.0255  max mem: 959
# Test: Total time: 0:00:01 (0.0665 s / it)
# Averaged stats: model_time: 0.0313 (0.0352)  evaluator_time: 0.0000 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.972
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.696
# Epoch: [2]  [ 0/48]  eta: 0:00:08  lr: 0.005000  loss: 0.1226 (0.1226)  loss_classifier: 0.0747 (0.0747)  loss_box_reg: 0.0395 (0.0395)  loss_objectness: 0.0005 (0.0005)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 0.1875  data: 0.1094  max mem: 959
# Epoch: [2]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0716 (0.0731)  loss_classifier: 0.0353 (0.0403)  loss_box_reg: 0.0254 (0.0262)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0058 (0.0058)  time: 0.2011  data: 0.1073  max mem: 959
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0537 (0.0673)  loss_classifier: 0.0312 (0.0364)  loss_box_reg: 0.0175 (0.0244)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0053 (0.0059)  time: 0.1979  data: 0.1045  max mem: 959
# Epoch: [2] Total time: 0:00:09 (0.1999 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0781  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0313 (0.0421)  evaluator_time: 0.0000 (0.0029)  time: 0.0675  data: 0.0215  max mem: 959
# Test: Total time: 0:00:01 (0.0685 s / it)
# Averaged stats: model_time: 0.0313 (0.0421)  evaluator_time: 0.0000 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.819
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.976
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.966
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.849
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.849
# Epoch: [3]  [ 0/48]  eta: 0:00:10  lr: 0.005000  loss: 0.0648 (0.0648)  loss_classifier: 0.0370 (0.0370)  loss_box_reg: 0.0189 (0.0189)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0087 (0.0087)  time: 0.2187  data: 0.1250  max mem: 959
# Epoch: [3]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0453 (0.0506)  loss_classifier: 0.0191 (0.0256)  loss_box_reg: 0.0168 (0.0191)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0054 (0.0055)  time: 0.2035  data: 0.1084  max mem: 959
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0442 (0.0496)  loss_classifier: 0.0236 (0.0257)  loss_box_reg: 0.0138 (0.0177)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0058 (0.0057)  time: 0.2011  data: 0.1104  max mem: 959
# Epoch: [3] Total time: 0:00:09 (0.2027 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:01  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0781  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0329)  evaluator_time: 0.0000 (0.0002)  time: 0.0635  data: 0.0304  max mem: 959
# Test: Total time: 0:00:01 (0.0635 s / it)
# Averaged stats: model_time: 0.0312 (0.0329)  evaluator_time: 0.0000 (0.0002)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.967
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.839
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.839
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.839
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.839
# Epoch: [4]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0349 (0.0349)  loss_classifier: 0.0208 (0.0208)  loss_box_reg: 0.0112 (0.0112)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 0.2031  data: 0.1094  max mem: 959
# Epoch: [4]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0403 (0.0404)  loss_classifier: 0.0224 (0.0221)  loss_box_reg: 0.0125 (0.0130)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0044 (0.0050)  time: 0.1968  data: 0.1062  max mem: 959
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0404 (0.0394)  loss_classifier: 0.0202 (0.0215)  loss_box_reg: 0.0122 (0.0125)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0053 (0.0051)  time: 0.1974  data: 0.1029  max mem: 959
# Epoch: [4] Total time: 0:00:09 (0.1973 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0156  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0322)  evaluator_time: 0.0000 (0.0034)  time: 0.0617  data: 0.0251  max mem: 959
# Test: Total time: 0:00:00 (0.0617 s / it)
# Averaged stats: model_time: 0.0312 (0.0322)  evaluator_time: 0.0000 (0.0034)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.869
# Epoch: [5]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0197 (0.0197)  loss_classifier: 0.0113 (0.0113)  loss_box_reg: 0.0055 (0.0055)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 0.2031  data: 0.1108  max mem: 959
# Epoch: [5]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0318 (0.0345)  loss_classifier: 0.0171 (0.0194)  loss_box_reg: 0.0091 (0.0103)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0044 (0.0047)  time: 0.1938  data: 0.1014  max mem: 959
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0338 (0.0357)  loss_classifier: 0.0202 (0.0201)  loss_box_reg: 0.0099 (0.0108)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0040 (0.0045)  time: 0.1959  data: 0.1047  max mem: 959
# Epoch: [5] Total time: 0:00:09 (0.1953 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0312  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0313)  evaluator_time: 0.0000 (0.0029)  time: 0.0615  data: 0.0264  max mem: 959
# Test: Total time: 0:00:00 (0.0615 s / it)
# Averaged stats: model_time: 0.0312 (0.0313)  evaluator_time: 0.0000 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.820
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.856
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.856
# Epoch: [6]  [ 0/48]  eta: 0:00:09  lr: 0.005000  loss: 0.0365 (0.0365)  loss_classifier: 0.0193 (0.0193)  loss_box_reg: 0.0118 (0.0118)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 0.2031  data: 0.1094  max mem: 959
# Epoch: [6]  [30/48]  eta: 0:00:03  lr: 0.005000  loss: 0.0286 (0.0344)  loss_classifier: 0.0160 (0.0192)  loss_box_reg: 0.0093 (0.0104)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0039 (0.0043)  time: 0.1957  data: 0.1040  max mem: 959
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0304 (0.0346)  loss_classifier: 0.0178 (0.0192)  loss_box_reg: 0.0088 (0.0104)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0044 (0.0046)  time: 0.1940  data: 0.1026  max mem: 959
# Epoch: [6] Total time: 0:00:09 (0.1957 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0469 (0.0469)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0156  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0353)  evaluator_time: 0.0000 (0.0029)  time: 0.0636  data: 0.0244  max mem: 959
# Test: Total time: 0:00:01 (0.0636 s / it)
# Averaged stats: model_time: 0.0312 (0.0353)  evaluator_time: 0.0000 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.833
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.860
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.863
# Epoch: [7]  [ 0/48]  eta: 0:00:08  lr: 0.000500  loss: 0.0281 (0.0281)  loss_classifier: 0.0126 (0.0126)  loss_box_reg: 0.0096 (0.0096)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 0.1875  data: 0.0937  max mem: 959
# Epoch: [7]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0255 (0.0276)  loss_classifier: 0.0156 (0.0163)  loss_box_reg: 0.0062 (0.0076)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0027 (0.0035)  time: 0.1994  data: 0.1047  max mem: 959
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0233 (0.0276)  loss_classifier: 0.0149 (0.0160)  loss_box_reg: 0.0065 (0.0080)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 0.1924  data: 0.0990  max mem: 959
# Epoch: [7] Total time: 0:00:09 (0.2019 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0323 (0.0323)  evaluator_time: 0.0000 (0.0000)  time: 0.0480  data: 0.0156  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0333)  evaluator_time: 0.0000 (0.0040)  time: 0.0617  data: 0.0225  max mem: 959
# Test: Total time: 0:00:01 (0.0627 s / it)
# Averaged stats: model_time: 0.0312 (0.0333)  evaluator_time: 0.0000 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.896
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.896
# Epoch: [8]  [ 0/48]  eta: 0:00:08  lr: 0.000500  loss: 0.0434 (0.0434)  loss_classifier: 0.0264 (0.0264)  loss_box_reg: 0.0122 (0.0122)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0036 (0.0036)  time: 0.1875  data: 0.0937  max mem: 959
# Epoch: [8]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0254 (0.0248)  loss_classifier: 0.0154 (0.0153)  loss_box_reg: 0.0059 (0.0065)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0026 (0.0028)  time: 0.1984  data: 0.1077  max mem: 959
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0228 (0.0255)  loss_classifier: 0.0151 (0.0155)  loss_box_reg: 0.0057 (0.0068)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0032 (0.0030)  time: 0.1964  data: 0.1034  max mem: 959
# Epoch: [8] Total time: 0:00:09 (0.1956 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0312  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0352)  evaluator_time: 0.0000 (0.0049)  time: 0.0646  data: 0.0245  max mem: 959
# Test: Total time: 0:00:01 (0.0646 s / it)
# Averaged stats: model_time: 0.0312 (0.0352)  evaluator_time: 0.0000 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.870
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.901
# Epoch: [9]  [ 0/48]  eta: 0:00:09  lr: 0.000500  loss: 0.0197 (0.0197)  loss_classifier: 0.0136 (0.0136)  loss_box_reg: 0.0040 (0.0040)  loss_objectness: 0.0000 (0.0000)  loss_rpn_box_reg: 0.0021 (0.0021)  time: 0.2031  data: 0.1094  max mem: 959
# Epoch: [9]  [30/48]  eta: 0:00:03  lr: 0.000500  loss: 0.0206 (0.0245)  loss_classifier: 0.0136 (0.0153)  loss_box_reg: 0.0052 (0.0062)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 0.1952  data: 0.1017  max mem: 959
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0244 (0.0247)  loss_classifier: 0.0146 (0.0152)  loss_box_reg: 0.0061 (0.0064)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0030 (0.0029)  time: 0.1943  data: 0.1003  max mem: 959
# Epoch: [9] Total time: 0:00:09 (0.1961 s / it)
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0361)  evaluator_time: 0.0000 (0.0029)  time: 0.0636  data: 0.0245  max mem: 959
# Test: Total time: 0:00:01 (0.0646 s / it)
# Averaged stats: model_time: 0.0312 (0.0361)  evaluator_time: 0.0000 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.861
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.894

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/16]  eta: 0:00:00  model_time: 0.0312 (0.0312)  evaluator_time: 0.0000 (0.0000)  time: 0.0625  data: 0.0313  max mem: 959
# Test:  [15/16]  eta: 0:00:00  model_time: 0.0312 (0.0303)  evaluator_time: 0.0000 (0.0025)  time: 0.0635  data: 0.0298  max mem: 959
# Test: Total time: 0:00:01 (0.0635 s / it)
# Averaged stats: model_time: 0.0312 (0.0303)  evaluator_time: 0.0000 (0.0025)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.861
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.861
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.894
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.894

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# Precision-Recall curves can be hard to interpret, and hence we also provide counts how many (left) images have at least one wrong detection / missed ground truth; and (right) the total number of wrong detections / missed ground truths summed over all images. These counts are shown for different detection score thresholds, ie. effectly discarding detections with confidence score lower than a given thresholds.
#
# As can be seen, the model performs well on the test dataset for thresholds between 0.5 and 0.9, but especially at a threshold of 0.5 over-fires on the negative images (images which do not contain any of the objects) since similar images were not included in the training set. This information is especially valuable when deciding on a precision-recall operating point. To avoid over-firing, one can either add more images to the training set directly or via hard-negative mining as explained in the [12_hard_negative_sampling.ipynb](12_hard_negative_sampling.ipynb) notebook.

# %%
# Run detector on the test images. Set threshold to 0 to keep all low confidence detections.
print(f"Running detector on {len(data.test_ds)} test images...") 
detections = detector.predict_dl(data.test_dl, threshold=0)

# Run detector on the negative images
if NEG_DATA_PATH is None or NEG_DATA_PATH == "":
    detections_neg = None
else:
    neg_data = DetectionDataset(NEG_DATA_PATH, train_pct=1.0, #, batch_size=BATCH_SIZE, 
                            im_dir = "", allow_negatives = True, 
                            train_transforms = get_transform(train=False))
    print(f"Running detector on {len(neg_data.train_ds)} negative images...") 
    detections_neg = detector.predict_dl(neg_data.train_dl, threshold=0)
    
# Count and plot number of wrong/missing detections
plot_counts_curves(detections, data.test_ds, detections_neg)
# Out:
# Running detector on 32 test images...
# Running detector on 64 negative images...

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 31,
#   'det_bboxes': [{Bbox object: [left=107, top=307, right=249, bottom=565] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\127.jpg} | score: 0.9996557235717773,
#    {Bbox object: [left=229, top=71, right=404, bottom=456] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\127.jpg} | score: 0.9995129108428955]},
#  {'idx': 43,
#   'det_bboxes': [{Bbox object: [left=16, top=272, right=337, bottom=496] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\22.jpg} | score: 0.9995823502540588,
#    {Bbox object: [left=313, top=254, right=449, bottom=500] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\22.jpg} | score: 0.9981583952903748]},
#  {'idx': 104,
#   'det_bboxes': [{Bbox object: [left=366, top=335, right=460, bottom=502] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\78.jpg} | score: 0.9991388320922852,
#    {Bbox object: [left=192, top=214, right=311, bottom=522] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\78.jpg} | score: 0.9988059997558594,
#    {Bbox object: [left=26, top=367, right=209, bottom=495] | <water_bottle> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\78.jpg} | score: 0.9979856014251709,
#    {Bbox object: [left=291, top=280, right=384, bottom=520] | <milk_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\78.jpg} | score: 0.9967369437217712]},
#  {'idx': 76,
#   'det_bboxes': [{Bbox object: [left=207, top=334, right=306, bottom=517] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\52.jpg} | score: 0.9998490810394287,
#    {Bbox object: [left=366, top=257, right=475, bottom=500] | <milk_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\52.jpg} | score: 0.9995661377906799,
#    {Bbox object: [left=31, top=198, right=176, bottom=497] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\52.jpg} | score: 0.9994603991508484]},
#  {'idx': 121,
#   'det_bboxes': [{Bbox object: [left=222, top=288, right=342, bottom=493] | <can> | label:1 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\93.jpg} | score: 0.9990867376327515,
#    {Bbox object: [left=306, top=152, right=392, bottom=302] | <milk_bottle> | label:2 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\93.jpg} | score: 0.9990168809890747,
#    {Bbox object: [left=107, top=161, right=230, bottom=488] | <water_bottle> | label:3 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\93.jpg} | score: 0.9976007342338562,
#    {Bbox object: [left=207, top=294, right=421, bottom=433] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\93.jpg} | score: 0.7787787914276123,
#    {Bbox object: [left=301, top=292, right=411, bottom=423] | <carton> | label:4 | path:C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\images\93.jpg} | score: 0.7420272827148438]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 32
# Number of test images: 32

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# WindowsPath('C:/Users/pabuehle/Desktop/ComputerVision/data/odFridgeObjects/images/91.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ## Save the model
# The final step is to save the model to disk. We'll do this since the deployment notebook will deploy this model.

# %%
if SAVE_MODEL:
    detector.save("my_drink_detector")
# Out:
# Model is saved to C:\Users\pabuehle\Desktop\ComputerVision\data\odFridgeObjects\models\my_drink_detector

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.

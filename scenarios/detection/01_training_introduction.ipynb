# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Training an Object Detection Model
#
# In this notebook, we give an introduction to training an object detection model using [torchvision](https://pytorch.org/docs/stable/torchvision/index.html). Using a small dataset, we demonstrate how to train and evaluate a FasterRCNN object detection model. We also cover one of the most common ways to store data on a file system for this type of problem.
#
# To learn more about how object detection work, visit our [FAQ](../FAQ.md).
#
# ## Initialization

# %% [markdown]
# Import all the functions we need.

# %%
import sys

sys.path.append("../../")

import os
import time
import matplotlib.pyplot as plt
from typing import Iterator
from pathlib import Path
from PIL import Image
from random import randrange
from typing import Tuple
import torch
import torchvision
from torchvision import transforms
import scrapbook as sb

from utils_cv.common.data import unzip_url, data_path
from utils_cv.detection.data import Urls
from utils_cv.detection.dataset import DetectionDataset
from utils_cv.detection.plot import (
    display_bboxes,
    plot_grid,
    plot_boxes,
    plot_pr_curves,
    PlotSettings,
    plot_detection_vs_ground_truth,
)
from utils_cv.detection.model import DetectionLearner, _get_det_bboxes, get_pretrained_fasterrcnn
from utils_cv.common.gpu import which_processor, is_windows

# Change matplotlib backend so that plots are shown for windows
if is_windows():
    plt.switch_backend('TkAgg')

print(f"TorchVision: {torchvision.__version__}")
which_processor()
# Out:
# TorchVision: 0.4.0a0
# Torch is using GPU: Tesla V100-PCIE-16GB

# %% [markdown]
# This shows your machine's GPUs (if it has any) and the computing device `torch/torchvision` is using.

# %%
# Ensure edits to libraries are loaded and plotting is shown in the notebook.
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# Next, set some model runtime parameters. We use the `unzip_url` helper function to download and unzip the data used in this example notebook.

# %%
DATA_PATH = unzip_url(Urls.fridge_objects_path, exist_ok=True)
EPOCHS = 10
LEARNING_RATE = 0.005
IM_SIZE = 500

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using torch device: {device}")
# Out:
# Using torch device: cuda

# %% [markdown]
# ---
#
# # Prepare Object Detection Dataset
#
# In this notebook, we use a toy dataset called *Fridge Objects*, which consists of 134 images of 4 classes of beverage container `{can, carton, milk bottle, water bottle}` photos taken on different backgrounds. The helper function downloads and unzips data set to the `ComputerVision/data` directory.
#
# Set that directory in the `path` variable for ease of use throughout the notebook.

# %%
path = Path(DATA_PATH)
os.listdir(path)
# Out:
# ['images', 'annotations', '.DS_Store']

# %% [markdown]
# You'll notice that we have two different folders inside:
# - `/images`
# - `/annotations`
#
# This format for object detection is fairly common.
#
# ```
# /data
# +-- images
# |   +-- image1.jpg
# |   +-- image2.jpg
# |   +-- ...
# +-- annotations
# |   +-- image1.xml
# |   +-- image2.xml
# |   +-- ...
# +-- ...
# ```
#
# Each image corresponds to an xml file. Each xml file contains information on where its corresponding image file is located. It also contains information about the bounding boxes and the object labels. In this example, our fridge object dataset is annotated in Pascal VOC format. This is one of the most common formats for labelling object detection datasets.
#
# ```xml
# <!-- Example Pascal VOC annotation -->
# <annotation>
#     <folder>images</folder>
#     <filename>1.jpg</filename>
#     <path>../images/1.jpg</path>
#     <source>
#         <database>Unknown</database>
#     </source>
#     <size>
#         <width>499</width>
#         <height>666</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#
#     <object>
#         <name>carton</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>100</xmin>
#             <ymin>173</ymin>
#             <xmax>233</xmax>
#             <ymax>521</ymax>
#         </bndbox>
#     </object>
# </annotation>
# ```
#
# You'll notice that inside the annotation xml file, we can see which image the file references `<path>`, the number of `<objects>` in the image, that the image is of (`<name>`) and the bounding box of that object (`<bndbox>`).

# %% [markdown]
# # Load Images
#
# To load the data, we need to create a Dataset object class that Torchvision knows how to use. In short, we'll need to create a class and implement the `__getitem__` method. More information here: https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html#defining-the-dataset
#
# To make it more convinient, we've created a `DetectionDataset` class that knows how to extract annotation information from the Pascal VOC format and meet the requirements of the Torchvision dataset object class.

# %%
data = DetectionDataset(DATA_PATH, train_pct=0.75)
# Out:
# ../../utils_cv/detection/dataset.py:62: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   if root.find("path"):

# %% [markdown]
# Inspect our Datasets/DataLoaders to make sure the train/test split looks right.

# %%
print(
    f"Training dataset: {len(data.train_ds)} | Training DataLoader: {data.train_dl} \nTesting dataset: {len(data.test_ds)} | Testing DataLoader: {data.test_dl}"
)
# Out:
# Training dataset: 96 | Training DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f8a479cf0b8>
# Testing dataset: 33 | Testing DataLoader: <torch.utils.data.dataloader.DataLoader object at 0x7f8a479cf198>

# %% [markdown]
# Lets visualize some of the images to make sure the annotation looks correct.

# %%
data.show_ims(rows=2)

# %% [markdown]
# # Finetune a Pretrained Model
#
# For the DetectionLearner, we use Faster R-CNN as the default model, and Stochastic Gradient Descent as our default optimizer.
#
# Our Faster R-CNN model is pretrained on COCO, a large-scale object detection, segmentation, and captioning dataset that contains over 200K labeled images with over 80 label cateogories.
#
# When we initialize the DetectionLearner, the only required parameter is the dataset. The object will set the model to torchvision's Faster R-CNN using the default parameters. However, we can customize the model using the `get_pretrained_fasterrcnn` function and specifying the parameters we want.

# %%
model = get_pretrained_fasterrcnn(
    num_classes=len(data.labels) + 1, min_size=IM_SIZE, max_size=IM_SIZE
)

# %% [markdown]
# We can now pass our Detection Learner object the model.

# %%
detector = DetectionLearner(data, model=model)

# %% [markdown]
# Lets also check that our model is properly set.

# %%
print(f"Model: {type(detector.model)}")
# Out:
# Model: <class 'torchvision.models.detection.faster_rcnn.FasterRCNN'>

# %% [markdown]
# Fine-tune the model using our training data loader (`train_dl`) and evaluate our results using our testing data loader (`test_dl`). Here we pass in the learning rate. If not set, the learning rate will automatically be set at 0.005.

# %%
detector.fit(EPOCHS, lr=LEARNING_RATE, print_freq=30)
# Out:
# Epoch: [0]  [ 0/48]  eta: 0:02:57  lr: 0.000111  loss: 1.3829 (1.3829)  loss_classifier: 1.1104 (1.1104)  loss_box_reg: 0.2665 (0.2665)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 3.6949  data: 0.7859  max mem: 664
# Epoch: [0]  [30/48]  eta: 0:00:04  lr: 0.003300  loss: 0.5197 (0.6805)  loss_classifier: 0.2425 (0.4332)  loss_box_reg: 0.2305 (0.2367)  loss_objectness: 0.0033 (0.0044)  loss_rpn_box_reg: 0.0054 (0.0062)  time: 0.1029  data: 0.0077  max mem: 958
# Epoch: [0]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.3416 (0.5569)  loss_classifier: 0.1790 (0.3410)  loss_box_reg: 0.1457 (0.2042)  loss_objectness: 0.0029 (0.0044)  loss_rpn_box_reg: 0.0085 (0.0073)  time: 0.1104  data: 0.0055  max mem: 958
# Epoch: [0] Total time: 0:00:09 (0.1962 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:15  model_time: 0.1366 (0.1366)  evaluator_time: 0.0071 (0.0071)  time: 0.9042  data: 0.7562  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0757 (0.0774)  evaluator_time: 0.0043 (0.0042)  time: 0.1394  data: 0.0487  max mem: 958
# Test: Total time: 0:00:02 (0.1468 s / it)
# Averaged stats: model_time: 0.0757 (0.0774)  evaluator_time: 0.0043 (0.0042)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.536
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.647
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.647
# Epoch: [1]  [ 0/48]  eta: 0:00:45  lr: 0.005000  loss: 0.3343 (0.3343)  loss_classifier: 0.2021 (0.2021)  loss_box_reg: 0.1163 (0.1163)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0158 (0.0158)  time: 0.9428  data: 0.7220  max mem: 958
# Epoch: [1]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.1129 (0.1488)  loss_classifier: 0.0699 (0.0879)  loss_box_reg: 0.0424 (0.0523)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0065 (0.0078)  time: 0.1027  data: 0.0041  max mem: 958
# Epoch: [1]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0809 (0.1277)  loss_classifier: 0.0412 (0.0742)  loss_box_reg: 0.0280 (0.0451)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0058 (0.0075)  time: 0.1280  data: 0.0062  max mem: 958
# Epoch: [1] Total time: 0:00:06 (0.1361 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0603 (0.0603)  evaluator_time: 0.0052 (0.0052)  time: 0.8096  data: 0.7288  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0583 (0.0623)  evaluator_time: 0.0031 (0.0031)  time: 0.1216  data: 0.0481  max mem: 958
# Test: Total time: 0:00:02 (0.1286 s / it)
# Averaged stats: model_time: 0.0583 (0.0623)  evaluator_time: 0.0031 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.785
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.808
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.808
# Epoch: [2]  [ 0/48]  eta: 0:00:46  lr: 0.005000  loss: 0.0920 (0.0920)  loss_classifier: 0.0434 (0.0434)  loss_box_reg: 0.0419 (0.0419)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 0.9717  data: 0.8398  max mem: 958
# Epoch: [2]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0573 (0.0608)  loss_classifier: 0.0298 (0.0315)  loss_box_reg: 0.0214 (0.0235)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0052 (0.0054)  time: 0.1131  data: 0.0037  max mem: 958
# Epoch: [2]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0471 (0.0577)  loss_classifier: 0.0252 (0.0297)  loss_box_reg: 0.0181 (0.0220)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0051 (0.0056)  time: 0.1342  data: 0.0074  max mem: 958
# Epoch: [2] Total time: 0:00:06 (0.1374 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0656 (0.0656)  evaluator_time: 0.0048 (0.0048)  time: 0.8030  data: 0.7263  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0621 (0.0628)  evaluator_time: 0.0032 (0.0030)  time: 0.1221  data: 0.0475  max mem: 958
# Test: Total time: 0:00:02 (0.1293 s / it)
# Averaged stats: model_time: 0.0621 (0.0628)  evaluator_time: 0.0032 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.844
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.867
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.867
# Epoch: [3]  [ 0/48]  eta: 0:00:43  lr: 0.005000  loss: 0.0851 (0.0851)  loss_classifier: 0.0401 (0.0401)  loss_box_reg: 0.0343 (0.0343)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0095 (0.0095)  time: 0.9148  data: 0.7718  max mem: 958
# Epoch: [3]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0347 (0.0457)  loss_classifier: 0.0213 (0.0235)  loss_box_reg: 0.0133 (0.0164)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0045 (0.0055)  time: 0.1149  data: 0.0054  max mem: 958
# Epoch: [3]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0365 (0.0428)  loss_classifier: 0.0182 (0.0218)  loss_box_reg: 0.0133 (0.0154)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0043 (0.0053)  time: 0.0846  data: 0.0050  max mem: 958
# Epoch: [3] Total time: 0:00:05 (0.1182 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0421 (0.0421)  evaluator_time: 0.0048 (0.0048)  time: 0.7817  data: 0.7322  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0303 (0.0305)  evaluator_time: 0.0029 (0.0028)  time: 0.0830  data: 0.0477  max mem: 958
# Test: Total time: 0:00:01 (0.0898 s / it)
# Averaged stats: model_time: 0.0303 (0.0305)  evaluator_time: 0.0029 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.865
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.865
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.884
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.884
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.884
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.884
# Epoch: [4]  [ 0/48]  eta: 0:00:42  lr: 0.005000  loss: 0.0240 (0.0240)  loss_classifier: 0.0141 (0.0141)  loss_box_reg: 0.0075 (0.0075)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 0.8857  data: 0.7538  max mem: 958
# Epoch: [4]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0307 (0.0334)  loss_classifier: 0.0175 (0.0186)  loss_box_reg: 0.0092 (0.0102)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0046 (0.0044)  time: 0.0847  data: 0.0061  max mem: 958
# Epoch: [4]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0282 (0.0341)  loss_classifier: 0.0159 (0.0192)  loss_box_reg: 0.0078 (0.0103)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0038 (0.0043)  time: 0.0852  data: 0.0053  max mem: 958
# Epoch: [4] Total time: 0:00:04 (0.1040 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0466 (0.0466)  evaluator_time: 0.0066 (0.0066)  time: 0.7729  data: 0.7161  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0307 (0.0317)  evaluator_time: 0.0027 (0.0029)  time: 0.0837  data: 0.0472  max mem: 958
# Test: Total time: 0:00:01 (0.0909 s / it)
# Averaged stats: model_time: 0.0307 (0.0317)  evaluator_time: 0.0027 (0.0029)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.881
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.901
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.901
# Epoch: [5]  [ 0/48]  eta: 0:00:42  lr: 0.005000  loss: 0.0590 (0.0590)  loss_classifier: 0.0283 (0.0283)  loss_box_reg: 0.0235 (0.0235)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.8802  data: 0.7342  max mem: 958
# Epoch: [5]  [30/48]  eta: 0:00:01  lr: 0.005000  loss: 0.0247 (0.0307)  loss_classifier: 0.0126 (0.0166)  loss_box_reg: 0.0081 (0.0099)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 0.0840  data: 0.0057  max mem: 958
# Epoch: [5]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0271 (0.0295)  loss_classifier: 0.0154 (0.0162)  loss_box_reg: 0.0073 (0.0092)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0031 (0.0039)  time: 0.0836  data: 0.0058  max mem: 958
# Epoch: [5] Total time: 0:00:04 (0.1030 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0422 (0.0422)  evaluator_time: 0.0046 (0.0046)  time: 0.7816  data: 0.7323  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0307 (0.0309)  evaluator_time: 0.0027 (0.0028)  time: 0.0832  data: 0.0476  max mem: 958
# Test: Total time: 0:00:01 (0.0906 s / it)
# Averaged stats: model_time: 0.0307 (0.0309)  evaluator_time: 0.0027 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.881
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.892
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.892
# Epoch: [6]  [ 0/48]  eta: 0:00:42  lr: 0.005000  loss: 0.0345 (0.0345)  loss_classifier: 0.0197 (0.0197)  loss_box_reg: 0.0104 (0.0104)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.8777  data: 0.7289  max mem: 958
# Epoch: [6]  [30/48]  eta: 0:00:02  lr: 0.005000  loss: 0.0255 (0.0295)  loss_classifier: 0.0142 (0.0170)  loss_box_reg: 0.0071 (0.0085)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0030 (0.0038)  time: 0.0830  data: 0.0039  max mem: 958
# Epoch: [6]  [47/48]  eta: 0:00:00  lr: 0.005000  loss: 0.0260 (0.0286)  loss_classifier: 0.0155 (0.0165)  loss_box_reg: 0.0075 (0.0082)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 0.0847  data: 0.0058  max mem: 958
# Epoch: [6] Total time: 0:00:05 (0.1052 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0416 (0.0416)  evaluator_time: 0.0047 (0.0047)  time: 0.7769  data: 0.7280  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0302 (0.0305)  evaluator_time: 0.0026 (0.0027)  time: 0.0824  data: 0.0474  max mem: 958
# Test: Total time: 0:00:01 (0.0897 s / it)
# Averaged stats: model_time: 0.0302 (0.0305)  evaluator_time: 0.0026 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.877
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.877
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.891
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.891
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.891
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.891
# Epoch: [7]  [ 0/48]  eta: 0:00:43  lr: 0.000500  loss: 0.0211 (0.0211)  loss_classifier: 0.0096 (0.0096)  loss_box_reg: 0.0073 (0.0073)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 0.9014  data: 0.7897  max mem: 958
# Epoch: [7]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0195 (0.0241)  loss_classifier: 0.0113 (0.0139)  loss_box_reg: 0.0044 (0.0064)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0027 (0.0036)  time: 0.0844  data: 0.0058  max mem: 958
# Epoch: [7]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0181 (0.0238)  loss_classifier: 0.0131 (0.0143)  loss_box_reg: 0.0041 (0.0061)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0021 (0.0031)  time: 0.0841  data: 0.0052  max mem: 958
# Epoch: [7] Total time: 0:00:04 (0.1041 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0417 (0.0417)  evaluator_time: 0.0048 (0.0048)  time: 0.7675  data: 0.7180  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0301 (0.0308)  evaluator_time: 0.0026 (0.0027)  time: 0.0830  data: 0.0475  max mem: 958
# Test: Total time: 0:00:01 (0.0913 s / it)
# Averaged stats: model_time: 0.0301 (0.0308)  evaluator_time: 0.0026 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.920
# Epoch: [8]  [ 0/48]  eta: 0:00:43  lr: 0.000500  loss: 0.0074 (0.0074)  loss_classifier: 0.0044 (0.0044)  loss_box_reg: 0.0017 (0.0017)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 0.8961  data: 0.7639  max mem: 958
# Epoch: [8]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0213 (0.0214)  loss_classifier: 0.0143 (0.0138)  loss_box_reg: 0.0048 (0.0052)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 0.0829  data: 0.0047  max mem: 958
# Epoch: [8]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0195 (0.0214)  loss_classifier: 0.0118 (0.0135)  loss_box_reg: 0.0041 (0.0053)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 0.0839  data: 0.0049  max mem: 958
# Epoch: [8] Total time: 0:00:04 (0.1039 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0430 (0.0430)  evaluator_time: 0.0046 (0.0046)  time: 0.7965  data: 0.7459  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0304 (0.0315)  evaluator_time: 0.0025 (0.0027)  time: 0.0851  data: 0.0490  max mem: 958
# Test: Total time: 0:00:01 (0.0916 s / it)
# Averaged stats: model_time: 0.0304 (0.0315)  evaluator_time: 0.0025 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.921
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.921
# Epoch: [9]  [ 0/48]  eta: 0:00:42  lr: 0.000500  loss: 0.0672 (0.0672)  loss_classifier: 0.0326 (0.0326)  loss_box_reg: 0.0278 (0.0278)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 0.8876  data: 0.7528  max mem: 958
# Epoch: [9]  [30/48]  eta: 0:00:01  lr: 0.000500  loss: 0.0207 (0.0238)  loss_classifier: 0.0125 (0.0156)  loss_box_reg: 0.0043 (0.0056)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0020 (0.0024)  time: 0.0830  data: 0.0049  max mem: 958
# Epoch: [9]  [47/48]  eta: 0:00:00  lr: 0.000500  loss: 0.0150 (0.0214)  loss_classifier: 0.0099 (0.0138)  loss_box_reg: 0.0038 (0.0051)  loss_objectness: 0.0001 (0.0002)  loss_rpn_box_reg: 0.0020 (0.0023)  time: 0.0830  data: 0.0051  max mem: 958
# Epoch: [9] Total time: 0:00:04 (0.1032 s / it)
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0428 (0.0428)  evaluator_time: 0.0050 (0.0050)  time: 0.7875  data: 0.7367  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0303 (0.0307)  evaluator_time: 0.0026 (0.0028)  time: 0.0846  data: 0.0488  max mem: 958
# Test: Total time: 0:00:01 (0.0917 s / it)
# Averaged stats: model_time: 0.0303 (0.0307)  evaluator_time: 0.0026 (0.0028)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.918

# %% [markdown]
# Visualize the loss and average precision (ap) over time.

# %%
detector.plot_precision_loss_curves()

# %% [markdown]
# # Evaluate

# %% [markdown]
# We can simply run the `evaluate()` method on our detector to evaluate the results.
#
# Below, you'll notice the notation IoU=0.5:0.95 in the results above. This means: the average mAP over different IoU thresholds, from 0.5 to 0.95, at step size of 0.05 (0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95). For more information on IoU and mAP, visit our [FAQ](../FAQ.md).

# %%
e = detector.evaluate()
# Out:
# creating index...
# index created!
# Test:  [ 0/17]  eta: 0:00:13  model_time: 0.0455 (0.0455)  evaluator_time: 0.0049 (0.0049)  time: 0.7959  data: 0.7424  max mem: 958
# Test:  [16/17]  eta: 0:00:00  model_time: 0.0304 (0.0308)  evaluator_time: 0.0026 (0.0027)  time: 0.0842  data: 0.0488  max mem: 958
# Test: Total time: 0:00:01 (0.0911 s / it)
# Averaged stats: model_time: 0.0304 (0.0308)  evaluator_time: 0.0026 (0.0027)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.902
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.902
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.918
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.918

# %% [markdown]
# Plot precision-recall curves. We'll use the `plot_pr_curves` function to plot the PR of each IoU threshold, and also the average over the IoU thresholds. If we look at the graph on the left, we can see that the lower the IOU threshold, the higher better the results are for the PR curve. This makes sense as the model is more lenient. This is why it is also a good idea to take a look at the mean over the IOU thresholds.

# %%
plot_pr_curves(e)

# %% [markdown]
# # Predict Batches

# %% [markdown]
# We can predict a group of images using the `predict_dl` function. We pass it a dataloader that references the images we want to predict and it will perform the predictions by the batch size specified when constructing the dataloader. In this case, we'll just use the test DataLoader (`test_dl`) that we created above. This dataloader uses the batch size set by the parameter `BATCH_SIZE`.

# %%
detections = detector.predict_dl(data.test_dl, threshold=0.5)

# %% [markdown]
# The `predict_dl` function returns a list of AnnotationBboxes. Lets print out 5 of the detection values.

# %%
detections[:5]
# Out:
# [{'idx': 113,
#   'det_bboxes': [{Bbox object: [left=358, top=239, right=464, bottom=496] | <milk_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/86.jpg} | score: 0.9993976354598999,
#    {Bbox object: [left=21, top=245, right=302, bottom=470] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/86.jpg} | score: 0.9993933439254761,
#    {Bbox object: [left=267, top=316, right=371, bottom=476] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/86.jpg} | score: 0.998691737651825,
#    {Bbox object: [left=76, top=425, right=361, bottom=541] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/86.jpg} | score: 0.9742738604545593]},
#  {'idx': 97,
#   'det_bboxes': [{Bbox object: [left=8, top=272, right=112, bottom=440] | <can> | label:3 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/71.jpg} | score: 0.9998013377189636,
#    {Bbox object: [left=70, top=340, right=375, bottom=567] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/71.jpg} | score: 0.999671220779419,
#    {Bbox object: [left=362, top=209, right=462, bottom=430] | <milk_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/71.jpg} | score: 0.9993352293968201,
#    {Bbox object: [left=238, top=173, right=323, bottom=368] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/71.jpg} | score: 0.9988540410995483]},
#  {'idx': 124,
#   'det_bboxes': [{Bbox object: [left=97, top=247, right=426, bottom=496] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/96.jpg} | score: 0.9995879530906677]},
#  {'idx': 25,
#   'det_bboxes': [{Bbox object: [left=161, top=371, right=475, bottom=505] | <milk_bottle> | label:4 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/121.jpg} | score: 0.9965274930000305,
#    {Bbox object: [left=32, top=293, right=344, bottom=402] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/121.jpg} | score: 0.9955490827560425]},
#  {'idx': 42,
#   'det_bboxes': [{Bbox object: [left=147, top=276, right=429, bottom=476] | <carton> | label:1 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/21.jpg} | score: 0.9972652196884155,
#    {Bbox object: [left=6, top=342, right=278, bottom=516] | <water_bottle> | label:2 | path:/home/jiata/code/computervision/data/odFridgeObjects/images/21.jpg} | score: 0.9960964322090149]}]

# %% [markdown]
# We can also verify that the length of the returned detections roughly equals the number of images in the test dataset.

# %%
print(f"Number of detections: {len(detections)}\nNumber of test images: {len(data.test_ds)}")
# Out:
# Number of detections: 33
# Number of test images: 33

# %% [markdown]
# > __Using a Generator Instead__
# >
# > Alternatively, we can use the `predict_batch` function if we'd rather get a generator object instead of _all_ the predictions back in one go. This may be preferable if the dataloader you are passing in contains many images and you don't want overflow your machine's memory.
# ```python
# detector_generator = detector.predict_batch(<dataloader>)
# one_batch_of_predictions = next(detector_generator)
# ```

# %% [markdown]
# We now have our predictions on the different images from our test set. Since the data is from the test set, we also know what the ground truth bounding boxes for those images are too. Lets plot the ground truth vs predictions for the images.
#
# To plot the predictions, we'll create a simple function (`get_im_and_bboxes()`) to create a generator that returns the data needed to plot the ground truths vs the detections. This generator returns a new image path (`im_path`), ground truth bounding boxes (`gt_bboxes`), and detection bounding boxes (`det_bboxes`) each time it is iterated on.
#
# Since these are the parameters that the `plot_detection_vs_ground_truth()` function takes, we can pass the entire iterator object to the `plot_grid()` function. For each plot it produces, it will use a new iteration from the generator.
#
# The red boxes represents the ground truth while the green represents the predected bounding box.

# %%
def get_im_and_bboxes() -> Iterator:
    for detection in detections:
        det_bboxes = detection["det_bboxes"]
        im_path = data.im_paths[detection["idx"]]
        gt_bboxes = data.anno_bboxes[detection["idx"]]
        yield im_path, gt_bboxes, det_bboxes

# %%
plot_grid(plot_detection_vs_ground_truth, get_im_and_bboxes(), rows=2)

# %% [markdown]
# # Predict Single Image
#
# We can use the detector to predict new images. Start by getting a new image. In this case, we'll reuse a random image in our dataset and pretend it is a new image.

# %%
new_im_path = data.root / data.im_dir / data.im_paths[randrange(len(data))]
new_im_path
# Out:
# PosixPath('/home/jiata/code/computervision/data/odFridgeObjects/images/17.jpg')

# %% [markdown]
# We can use the inference function:

# %%
new_im = Image.open(new_im_path)
detections = detector.predict(new_im, threshold=None)

# %% [markdown]
# Now that we have our predictions, lets plot the predictions on our image.

# %%
plot_settings = PlotSettings(rect_color=(0, 255, 0))

display_bboxes(
    detections,
    new_im_path,
    plot_settings=plot_settings,
)

# %% [markdown]
# ---

# %%
# Preserve some of the notebook outputs
sb.glue("training_losses", detector.losses)
sb.glue("training_average_precision", detector.ap)

# %% [markdown]
# # Conclusion
#
# Using the concepts introduced in this notebook, you can bring your own dataset and train an object detector to find objects of interest in a given image.
